# %%
import pandas as pd
import re
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# set width  - 100
pd.options.display.max_colwidth=500

# %%
data=pd.read_excel('./selenagomez.xlsx')
del data['Unnamed: 0']
data
# Out:
#                            created_at         username  \
# 0      Thu Mar 02 23:59:54 +0000 2023      izzvhatirvh
# 1      Thu Mar 02 23:59:44 +0000 2023  Kenzie5Peterson
# 2      Thu Mar 02 23:59:44 +0000 2023        sammii_gv
# 3      Thu Mar 02 23:59:36 +0000 2023        _xolesley
# 4      Thu Mar 02 23:59:34 +0000 2023  DoncasterAlexis
# ...                               ...              ...
# 11640  Wed Mar 01 10:17:49 +0000 2023         jiminlvv
# 11641  Wed Mar 01 10:16:29 +0000 2023        maxxxialv
# 11642  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 11643  Wed Mar 01 10:15:12 +0000 2023  abiwithaninotay
# 11644  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                                                                                                               text
# 0                               RT @armylieber100: Aren't Selena Gomez fans tired yet? it's been almost a week like move on and leave Hailey alone
# 1                                                                                 RT @juliannarvivas: Im a Selena Gomez &amp; you a Hailey Bieber.
# 2                                                                                 RT @juliannarvivas: Im a Selena Gomez &amp; you a Hailey Bieber.
# 3                                                             RT @kvnnrxa: justin bieber and selena gomez follow eachother. id kms if i was hailey
# 4                                                                                 RT @juliannarvivas: Im a Selena Gomez &amp; you a Hailey Bieber.
# ...                                                                                                                                            ...
# 11640              RT @TaurusBabez11: Kylie jenner and hailey bieber, a mother and a wife bullying Selena Gomez is so ‘highschool bully’ behavior😭
# 11641                          RT @riveragrcn: @KingMadTaz @PopCrave cause she’s selena gomez not a fictional character from a disney channel show
# 11642                                                                       I still can taste it and i hate it. \n\nPeople you know - Selena Gomez
# 11643  RT @p1scesinacrisis: hailey bieber is such a pick me girl. it’s crazy her and her lil friend group of mean girls are always shading selena…
# 11644  Over the past few days, the alleged feud between Selena Gomez and Hailey Bieber has captured the attention of news… https://t.co/mIRispzU5z
#
# [11645 rows x 3 columns]

# %%
data = data[data["text"].str.contains("RT") == False]
data
# Out:
#                            created_at         username  \
# 5      Thu Mar 02 23:59:30 +0000 2023        darkonsun
# 25     Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 28     Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 29     Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 32     Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...                               ...              ...
# 11634  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 11635  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 11638  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 11642  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 11644  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                                                                                                               text
# 5                                                                     social media is a disease and this hailey bieber selena gomez tea is too hot
# 25                                                         Justin Bieber &amp; Selena Gomez followed each other on Twitter 😭teenage me is crying 😭
# 28                                                                                                                Selena Gomez drove by my house 🙀
# 29                                                        I understand hailey Bieber because if my husbands ex was Selena Gomez I’d be worried too
# 32                                                                             but then i always realize because SELENA GOMEZ ALWAYS LOOKS GOOD 😭🫶
# ...                                                                                                                                            ...
# 11634             @SAFFAOnAirRadio is now playing, Selena Gomez, Marshmello - Wolves. Streaming live via the @TheSaffaApp… https://t.co/JZi20yk5NM
# 11635                                                                                                               Go follow Selena Gomez on IG 😡
# 11638                                                             @Ricius496 @endlessbonerz Selena Gomez has a medical issue she's still a baddie.
# 11642                                                                       I still can taste it and i hate it. \n\nPeople you know - Selena Gomez
# 11644  Over the past few days, the alleged feud between Selena Gomez and Hailey Bieber has captured the attention of news… https://t.co/mIRispzU5z
#
# [5206 rows x 3 columns]

# %%
#Lower text
def lowercase(text):
    return text.lower()

# %%
temp=data['text'].apply(lowercase)
temp
# Out:
# 5                                                                       social media is a disease and this hailey bieber selena gomez tea is too hot
# 25                                                           justin bieber &amp; selena gomez followed each other on twitter 😭teenage me is crying 😭
# 28                                                                                                                  selena gomez drove by my house 🙀
# 29                                                          i understand hailey bieber because if my husbands ex was selena gomez i’d be worried too
# 32                                                                               but then i always realize because selena gomez always looks good 😭🫶
#                                                                             ...
# 11634               @saffaonairradio is now playing, selena gomez, marshmello - wolves. streaming live via the @thesaffaapp… https://t.co/jzi20yk5nm
# 11635                                                                                                                 go follow selena gomez on ig 😡
# 11638                                                               @ricius496 @endlessbonerz selena gomez has a medical issue she's still a baddie.
# 11642                                                                         i still can taste it and i hate it. \n\npeople you know - selena gomez
# 11644    over the past few days, the alleged feud between selena gomez and hailey bieber has captured the attention of news… https://t.co/mirispzu5z
# Name: text, Length: 5206, dtype: object

# %%
#Remove unnecessary charracters
def removeUnnecessary(text):
    text=re.sub('\n','',text) # menghapus newline
    text=re.sub('rt','',text) # menghapus kata retweet
    text=re.sub('user','',text) # menghapus kata user
    text=re.sub(r"http\S+", "", text)
    text = re.sub('  +', ' ', text) # menghapus karakter ekstra
    text=re.sub('x.{3} | x.{2}','',text) # menghapus pola emoji 
    return text

# %%
temp=temp.apply(removeUnnecessary)
temp
# Out:
# 5                                                social media is a disease and this hailey bieber selena gomez tea is too hot
# 25                                    justin bieber &amp; selena gomez followed each other on twitter 😭teenage me is crying 😭
# 28                                                                                           selena gomez drove by my house 🙀
# 29                                   i understand hailey bieber because if my husbands ex was selena gomez i’d be worried too
# 32                                                        but then i always realize because selena gomez always looks good 😭🫶
#                                                                  ...
# 11634               @saffaonairradio is now playing, selena gomez, marshmello - wolves. streaming live via the @thesaffaapp…
# 11635                                                                                          go follow selena gomez on ig 😡
# 11638                                        @ricius496 @endlessbonerz selena gomez has a medical issue she's still a baddie.
# 11642                                                      i still can taste it and i hate it. people you know - selena gomez
# 11644    over the past few days, the alleged feud between selena gomez and hailey bieber has captured the attention of news…
# Name: text, Length: 5206, dtype: object

# %%
#Remove non alphanumeric character
def removeNonAlphanumeric(text):
    text = re.sub('[^0-9a-zA-Z]+', ' ', text) 
    return text

# %%
temp=temp.apply(removeNonAlphanumeric)
temp
# Out:
# 5                                              social media is a disease and this hailey bieber selena gomez tea is too hot
# 25                                      justin bieber amp selena gomez followed each other on twitter teenage me is crying
# 28                                                                                          selena gomez drove by my house
# 29                                 i understand hailey bieber because if my husbands ex was selena gomez i d be worried too
# 32                                                        but then i always realize because selena gomez always looks good
#                                                                 ...
# 11634                     saffaonairradio is now playing selena gomez marshmello wolves streaming live via the thesaffaapp
# 11635                                                                                         go follow selena gomez on ig
# 11638                                        ricius496 endlessbonerz selena gomez has a medical issue she s still a baddie
# 11642                                                       i still can taste it and i hate it people you know selena gomez
# 11644    over the past few days the alleged feud between selena gomez and hailey bieber has captured the attention of news
# Name: text, Length: 5206, dtype: object

# %%
def removeStopWord(text):
    stop_words = set(stopwords.words("english"))
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word not in stop_words]
    return ' '.join(filtered_text)

# %%
temp=temp.apply(removeStopWord)
temp
# Out:
# 5                                      social media disease hailey bieber selena gomez tea hot
# 25                              justin bieber amp selena gomez followed twitter teenage crying
# 28                                                                    selena gomez drove house
# 29                                   understand hailey bieber husbands ex selena gomez worried
# 32                                               always realize selena gomez always looks good
#                                                  ...
# 11634    saffaonairradio playing selena gomez marshmello wolves streaming live via thesaffaapp
# 11635                                                                go follow selena gomez ig
# 11638                          ricius496 endlessbonerz selena gomez medical issue still baddie
# 11642                                                still taste hate people know selena gomez
# 11644                past days alleged feud selena gomez hailey bieber captured attention news
# Name: text, Length: 5206, dtype: object

# %%
#Stemming text
def stemWord(text):
    word_tokens = word_tokenize(text)
    stems = [stemmer.stem(word) for word in word_tokens]
    return ' '.join(stems)

# %%
def lemmatizeWord(text):
    word_tokens = word_tokenize(text)
    # provide context i.e. part-of-speech
    lemmas = [lemmatizer.lemmatize(word, pos ='v') for word in word_tokens]
    return ' '.join(lemmas)

# %%
temp=temp.apply(lemmatizeWord)
temp
# Out:
# 5                                social media disease hailey bieber selena gomez tea hot
# 25                             justin bieber amp selena gomez follow twitter teenage cry
# 28                                                              selena gomez drive house
# 29                                understand hailey bieber husband ex selena gomez worry
# 32                                          always realize selena gomez always look good
#                                               ...
# 11634    saffaonairradio play selena gomez marshmello wolves stream live via thesaffaapp
# 11635                                                          go follow selena gomez ig
# 11638                    ricius496 endlessbonerz selena gomez medical issue still baddie
# 11642                                          still taste hate people know selena gomez
# 11644            past days allege feud selena gomez hailey bieber capture attention news
# Name: text, Length: 5206, dtype: object

# %%
def preProcessing(sentences):
    sentences=lowercase(sentences)
    sentences=removeUnnecessary(sentences)
    sentences=removeNonAlphanumeric(sentences)
    sentences=removeStopWord(sentences)
    #sentences=stemWord(sentences)
    sentences=lemmatizeWord(sentences)
    return sentences

# %%
data['preprocessed']=data['text'].apply(preProcessing)
data
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18104\2441838064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['preprocessed']=data['text'].apply(preProcessing)
#                            created_at         username  \
# 5      Thu Mar 02 23:59:30 +0000 2023        darkonsun
# 25     Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 28     Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 29     Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 32     Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...                               ...              ...
# 11634  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 11635  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 11638  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 11642  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 11644  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                                                                                                               text  \
# 5                                                                     social media is a disease and this hailey bieber selena gomez tea is too hot
# 25                                                         Justin Bieber &amp; Selena Gomez followed each other on Twitter 😭teenage me is crying 😭
# 28                                                                                                                Selena Gomez drove by my house 🙀
# 29                                                        I understand hailey Bieber because if my husbands ex was Selena Gomez I’d be worried too
# 32                                                                             but then i always realize because SELENA GOMEZ ALWAYS LOOKS GOOD 😭🫶
# ...                                                                                                                                            ...
# 11634             @SAFFAOnAirRadio is now playing, Selena Gomez, Marshmello - Wolves. Streaming live via the @TheSaffaApp… https://t.co/JZi20yk5NM
# 11635                                                                                                               Go follow Selena Gomez on IG 😡
# 11638                                                             @Ricius496 @endlessbonerz Selena Gomez has a medical issue she's still a baddie.
# 11642                                                                       I still can taste it and i hate it. \n\nPeople you know - Selena Gomez
# 11644  Over the past few days, the alleged feud between Selena Gomez and Hailey Bieber has captured the attention of news… https://t.co/mIRispzU5z
#
#                                                                           preprocessed
# 5                              social media disease hailey bieber selena gomez tea hot
# 25                           justin bieber amp selena gomez follow twitter teenage cry
# 28                                                            selena gomez drive house
# 29                              understand hailey bieber husband ex selena gomez worry
# 32                                        always realize selena gomez always look good
# ...                                                                                ...
# 11634  saffaonairradio play selena gomez marshmello wolves stream live via thesaffaapp
# 11635                                                        go follow selena gomez ig
# 11638                  ricius496 endlessbonerz selena gomez medical issue still baddie
# 11642                                        still taste hate people know selena gomez
# 11644          past days allege feud selena gomez hailey bieber capture attention news
#
# [5206 rows x 4 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
 
# function to print sentiments
# of the sentence.
def sentiment_scores(sentence):
 
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
 
    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)
     
 
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0.05 :
        return "Positive"
 
    elif sentiment_dict['compound'] <= - 0.05 :
        return "Negative"
 
    else :
        return "Neutral"

def sentiment_score2(sentence):
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
 
    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)
     
 
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0 :
        return "Positive"
 
    else :
        return "Negative"

# %%
data['sentiment']=data['preprocessed'].apply(sentiment_scores)
data['sentiment'].value_counts()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18104\3227507766.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sentiment']=data['preprocessed'].apply(sentiment_scores)
# Positive    2091
# Neutral     1828
# Negative    1287
# Name: sentiment, dtype: int64

# %%
data
# Out:
#                            created_at         username  \
# 5      Thu Mar 02 23:59:30 +0000 2023        darkonsun
# 25     Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 28     Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 29     Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 32     Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...                               ...              ...
# 11634  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 11635  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 11638  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 11642  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 11644  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                                                                                                               text  \
# 5                                                                     social media is a disease and this hailey bieber selena gomez tea is too hot
# 25                                                         Justin Bieber &amp; Selena Gomez followed each other on Twitter 😭teenage me is crying 😭
# 28                                                                                                                Selena Gomez drove by my house 🙀
# 29                                                        I understand hailey Bieber because if my husbands ex was Selena Gomez I’d be worried too
# 32                                                                             but then i always realize because SELENA GOMEZ ALWAYS LOOKS GOOD 😭🫶
# ...                                                                                                                                            ...
# 11634             @SAFFAOnAirRadio is now playing, Selena Gomez, Marshmello - Wolves. Streaming live via the @TheSaffaApp… https://t.co/JZi20yk5NM
# 11635                                                                                                               Go follow Selena Gomez on IG 😡
# 11638                                                             @Ricius496 @endlessbonerz Selena Gomez has a medical issue she's still a baddie.
# 11642                                                                       I still can taste it and i hate it. \n\nPeople you know - Selena Gomez
# 11644  Over the past few days, the alleged feud between Selena Gomez and Hailey Bieber has captured the attention of news… https://t.co/mIRispzU5z
#
#                                                                           preprocessed  \
# 5                              social media disease hailey bieber selena gomez tea hot
# 25                           justin bieber amp selena gomez follow twitter teenage cry
# 28                                                            selena gomez drive house
# 29                              understand hailey bieber husband ex selena gomez worry
# 32                                        always realize selena gomez always look good
# ...                                                                                ...
# 11634  saffaonairradio play selena gomez marshmello wolves stream live via thesaffaapp
# 11635                                                        go follow selena gomez ig
# 11638                  ricius496 endlessbonerz selena gomez medical issue still baddie
# 11642                                        still taste hate people know selena gomez
# 11644          past days allege feud selena gomez hailey bieber capture attention news
#
#       sentiment
# 5       Neutral
# 25     Negative
# 28      Neutral
# 29     Negative
# 32     Positive
# ...         ...
# 11634  Positive
# 11635   Neutral
# 11638   Neutral
# 11642  Negative
# 11644  Negative
#
# [5206 rows x 5 columns]

# %%
data.to_excel('selenagomez_clean_new.xlsx')

# %%
data=pd.read_excel('selenagomez_clean_new.xlsx')
data
# Out:
#       Unnamed: 0                      created_at         username  \
# 0              5  Thu Mar 02 23:59:30 +0000 2023        darkonsun
# 1             25  Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 2             28  Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 3             29  Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 4             32  Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...          ...                             ...              ...
# 5201       11634  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 5202       11635  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 5203       11638  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 5204       11642  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 5205       11644  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                                                                                                              text  \
# 0                                                                    social media is a disease and this hailey bieber selena gomez tea is too hot
# 1                                                         Justin Bieber &amp; Selena Gomez followed each other on Twitter 😭teenage me is crying 😭
# 2                                                                                                                Selena Gomez drove by my house 🙀
# 3                                                        I understand hailey Bieber because if my husbands ex was Selena Gomez I’d be worried too
# 4                                                                             but then i always realize because SELENA GOMEZ ALWAYS LOOKS GOOD 😭🫶
# ...                                                                                                                                           ...
# 5201             @SAFFAOnAirRadio is now playing, Selena Gomez, Marshmello - Wolves. Streaming live via the @TheSaffaApp… https://t.co/JZi20yk5NM
# 5202                                                                                                               Go follow Selena Gomez on IG 😡
# 5203                                                             @Ricius496 @endlessbonerz Selena Gomez has a medical issue she's still a baddie.
# 5204                                                                       I still can taste it and i hate it. \n\nPeople you know - Selena Gomez
# 5205  Over the past few days, the alleged feud between Selena Gomez and Hailey Bieber has captured the attention of news… https://t.co/mIRispzU5z
#
#                                                                        preprocessed  \
# 0                            social media diseas hailey bieber selena gomez tea hot
# 1                          justin bieber amp selena gomez follow twitter teenag cri
# 2                                                           selena gomez drive hous
# 3                            understand hailey bieber husband ex selena gomez worri
# 4                                         alway realiz selena gomez alway look good
# ...                                                                             ...
# 5201  saffaonairradio play selena gomez marshmello wolv stream live via thesaffaapp
# 5202                                                      go follow selena gomez ig
# 5203                    ricius496 endlessbonerz selena gomez medic issu still baddi
# 5204                                        still tast hate peopl know selena gomez
# 5205              past day alleg feud selena gomez hailey bieber captur attent news
#
#      sentiment
# 0      Neutral
# 1      Neutral
# 2      Neutral
# 3      Neutral
# 4     Positive
# ...        ...
# 5201  Positive
# 5202   Neutral
# 5203   Neutral
# 5204  Negative
# 5205  Negative
#
# [5206 rows x 6 columns]
