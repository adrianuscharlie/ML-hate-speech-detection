# %%
import pandas as pd
import re
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
data=pd.read_excel('./selenagomez.xlsx')
del data['Unnamed: 0']
data
# Out:
#                            created_at         username  \
# 0      Thu Mar 02 23:59:54 +0000 2023      izzvhatirvh
# 1      Thu Mar 02 23:59:44 +0000 2023  Kenzie5Peterson
# 2      Thu Mar 02 23:59:44 +0000 2023        sammii_gv
# 3      Thu Mar 02 23:59:36 +0000 2023        _xolesley
# 4      Thu Mar 02 23:59:34 +0000 2023  DoncasterAlexis
# ...                               ...              ...
# 11640  Wed Mar 01 10:17:49 +0000 2023         jiminlvv
# 11641  Wed Mar 01 10:16:29 +0000 2023        maxxxialv
# 11642  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 11643  Wed Mar 01 10:15:12 +0000 2023  abiwithaninotay
# 11644  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                     text
# 0      RT @armylieber100: Aren't Selena Gomez fans ti...
# 1      RT @juliannarvivas: Im a Selena Gomez &amp; yo...
# 2      RT @juliannarvivas: Im a Selena Gomez &amp; yo...
# 3      RT @kvnnrxa: justin bieber and selena gomez fo...
# 4      RT @juliannarvivas: Im a Selena Gomez &amp; yo...
# ...                                                  ...
# 11640  RT @TaurusBabez11: Kylie jenner and hailey bie...
# 11641  RT @riveragrcn: @KingMadTaz @PopCrave cause sh...
# 11642  I still can taste it and i hate it. \n\nPeople...
# 11643  RT @p1scesinacrisis: hailey bieber is such a p...
# 11644  Over the past few days, the alleged feud betwe...
#
# [11645 rows x 3 columns]

# %%
data = data[data["text"].str.contains("RT") == False]
data
# Out:
#                            created_at         username  \
# 5      Thu Mar 02 23:59:30 +0000 2023        darkonsun
# 25     Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 28     Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 29     Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 32     Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...                               ...              ...
# 11634  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 11635  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 11638  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 11642  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 11644  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                     text
# 5      social media is a disease and this hailey bieb...
# 25     Justin Bieber &amp; Selena Gomez followed each...
# 28                      Selena Gomez drove by my house 🙀
# 29     I understand hailey Bieber because if my husba...
# 32     but then i always realize because SELENA GOMEZ...
# ...                                                  ...
# 11634  @SAFFAOnAirRadio is now playing, Selena Gomez,...
# 11635                     Go follow Selena Gomez on IG 😡
# 11638  @Ricius496 @endlessbonerz Selena Gomez has a m...
# 11642  I still can taste it and i hate it. \n\nPeople...
# 11644  Over the past few days, the alleged feud betwe...
#
# [5206 rows x 3 columns]

# %%
#Lower text
def lowercase(text):
    return text.lower()

# %%
lower=data['text'].apply(lowercase)
lower
# Out:
# 5        social media is a disease and this hailey bieb...
# 25       justin bieber &amp; selena gomez followed each...
# 28                        selena gomez drove by my house 🙀
# 29       i understand hailey bieber because if my husba...
# 32       but then i always realize because selena gomez...
#                                ...
# 11634    @saffaonairradio is now playing, selena gomez,...
# 11635                       go follow selena gomez on ig 😡
# 11638    @ricius496 @endlessbonerz selena gomez has a m...
# 11642    i still can taste it and i hate it. \n\npeople...
# 11644    over the past few days, the alleged feud betwe...
# Name: text, Length: 5206, dtype: object

# %%
#Remove non alphanumeric character
def removeNonAlphanumeric(text):
    text = re.sub('[^0-9a-zA-Z]+', ' ', text) 
    text="".join(filter(lambda x: not x.isdigit(), text))
    return text

# %%
nonAlpha=lower.apply(removeNonAlphanumeric)
nonAlpha
# Out:
# 5        social media is a disease and this hailey bieb...
# 25       justin bieber amp selena gomez followed each o...
# 28                         selena gomez drove by my house
# 29       i understand hailey bieber because if my husba...
# 32       but then i always realize because selena gomez...
#                                ...
# 11634     saffaonairradio is now playing selena gomez m...
# 11635                        go follow selena gomez on ig
# 11638     ricius endlessbonerz selena gomez has a medic...
# 11642    i still can taste it and i hate it people you ...
# 11644    over the past few days the alleged feud betwee...
# Name: text, Length: 5206, dtype: object

# %%
def removeNumbers(text):
    text = ''.join([i for i in text if not i.isdigit()])         
    return text

# %%
#Remove unnecessary charracters
def removeUnnecessary(text):
    text=re.sub('\n','',text) # menghapus newline
    text=re.sub('rt','',text) # menghapus kata retweet
    text=re.sub('user','',text) # menghapus kata user
    text=re.sub('((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))','',text) # menghapus url
    text = re.sub('  +', ' ', text) # menghapus karakter ekstra
    text=re.sub('x.{3} | x.{2}','',text) # menghapus pola emoji 
    return text

# %%
khusus=nonAlpha.apply(removeUnnecessary)
khusus
# Out:
# 5        social media is a disease and this hailey bieb...
# 25       justin bieber amp selena gomez followed each o...
# 28                         selena gomez drove by my house
# 29       i understand hailey bieber because if my husba...
# 32       but then i always realize because selena gomez...
#                                ...
# 11634     saffaonairradio is now playing selena gomez m...
# 11635                        go follow selena gomez on ig
# 11638     ricius endlessbonerz selena gomez has a medic...
# 11642    i still can taste it and i hate it people you ...
# 11644    over the past few days the alleged feud betwee...
# Name: text, Length: 5206, dtype: object

# %%
def removeStopWord(text):
    stop_words = set(stopwords.words("english"))
    word_tokens = word_tokenize(text)
    filtered_text = [word for word in word_tokens if word not in stop_words]
    return ' '.join(filtered_text)

# %%
stopWords=khusus.apply(removeStopWord)
stopWords
# Out:
# 5        social media disease hailey bieber selena gome...
# 25       justin bieber amp selena gomez followed twitte...
# 28                                selena gomez drove house
# 29       understand hailey bieber husbands ex selena go...
# 32           always realize selena gomez always looks good
#                                ...
# 11634    saffaonairradio playing selena gomez marshmell...
# 11635                            go follow selena gomez ig
# 11638    ricius endlessbonerz selena gomez medical issu...
# 11642            still taste hate people know selena gomez
# 11644    past days alleged feud selena gomez hailey bie...
# Name: text, Length: 5206, dtype: object

# %%
#Stemming text
def stemWord(text):
    word_tokens = word_tokenize(text)
    stems = [stemmer.stem(word) for word in word_tokens]
    return ' '.join(stems)

# %%
stem=stopWords.apply(stemWord)
stem
# Out:
# 5        social media diseas hailey bieber selena gomez...
# 25       justin bieber amp selena gomez follow twitter ...
# 28                                 selena gomez drove hous
# 29       understand hailey bieber husband ex selena gom...
# 32               alway realiz selena gomez alway look good
#                                ...
# 11634    saffaonairradio play selena gomez marshmello w...
# 11635                            go follow selena gomez ig
# 11638    riciu endlessbonerz selena gomez medic issu st...
# 11642              still tast hate peopl know selena gomez
# 11644    past day alleg feud selena gomez hailey bieber...
# Name: text, Length: 5206, dtype: object

# %%
def lemmatizeWord(text):
    word_tokens = word_tokenize(text)
    # provide context i.e. part-of-speech
    lemmas = [lemmatizer.lemmatize(word, pos ='v') for word in word_tokens]
    return ' '.join(lemmas)

# %%
lemma=stem.apply(lemmatizeWord)
lemma
# Out:
# 5        social media diseas hailey bieber selena gomez...
# 25       justin bieber amp selena gomez follow twitter ...
# 28                                 selena gomez drive hous
# 29       understand hailey bieber husband ex selena gom...
# 32               alway realiz selena gomez alway look good
#                                ...
# 11634    saffaonairradio play selena gomez marshmello w...
# 11635                            go follow selena gomez ig
# 11638    riciu endlessbonerz selena gomez medic issu st...
# 11642              still tast hate peopl know selena gomez
# 11644    past day alleg feud selena gomez hailey bieber...
# Name: text, Length: 5206, dtype: object

# %%
def preProcessing(sentences):
    sentences=lowercase(sentences)
    sentences=removeNonAlphanumeric(sentences)
    sentences=removeUnnecessary(sentences)
    sentences=removeStopWord(sentences)
    sentences=stemWord(sentences)
    sentences=lemmatizeWord(sentences)
    return sentences

# %%
data['preprocessed']=data['text'].apply(preProcessing)
data
# Out:
#                            created_at         username  \
# 5      Thu Mar 02 23:59:30 +0000 2023        darkonsun
# 25     Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 28     Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 29     Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 32     Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...                               ...              ...
# 11634  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 11635  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 11638  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 11642  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 11644  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                     text  \
# 5      social media is a disease and this hailey bieb...
# 25     Justin Bieber &amp; Selena Gomez followed each...
# 28                      Selena Gomez drove by my house 🙀
# 29     I understand hailey Bieber because if my husba...
# 32     but then i always realize because SELENA GOMEZ...
# ...                                                  ...
# 11634  @SAFFAOnAirRadio is now playing, Selena Gomez,...
# 11635                     Go follow Selena Gomez on IG 😡
# 11638  @Ricius496 @endlessbonerz Selena Gomez has a m...
# 11642  I still can taste it and i hate it. \n\nPeople...
# 11644  Over the past few days, the alleged feud betwe...
#
#                                             preprocessed
# 5      social media diseas hailey bieber selena gomez...
# 25     justin bieber amp selena gomez follow twitter ...
# 28                               selena gomez drive hous
# 29     understand hailey bieber husband ex selena gom...
# 32             alway realiz selena gomez alway look good
# ...                                                  ...
# 11634  saffaonairradio play selena gomez marshmello w...
# 11635                          go follow selena gomez ig
# 11638  riciu endlessbonerz selena gomez medic issu st...
# 11642            still tast hate peopl know selena gomez
# 11644  past day alleg feud selena gomez hailey bieber...
#
# [5206 rows x 4 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
 
# function to print sentiments
# of the sentence.
def sentiment_scores(sentence):
 
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
 
    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)
     
 
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0.05 :
        return "Positive"
 
    elif sentiment_dict['compound'] <= - 0.05 :
        return "Negative"
 
    else :
        return "Neutral"

def sentiment_score2(sentence):
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
 
    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)
     
 
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0 :
        return "Positive"
 
    else :
        return "Negative"

# %%
data['sentiment']=data['preprocessed'].apply(sentiment_scores)
data['sentiment'].value_counts()
# Out:
# Neutral     2103
# Positive    1942
# Negative    1161
# Name: sentiment, dtype: int64

# %%
data
# Out:
#                            created_at         username  \
# 5      Thu Mar 02 23:59:30 +0000 2023        darkonsun
# 25     Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 28     Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 29     Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 32     Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...                               ...              ...
# 11634  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 11635  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 11638  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 11642  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 11644  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                     text  \
# 5      social media is a disease and this hailey bieb...
# 25     Justin Bieber &amp; Selena Gomez followed each...
# 28                      Selena Gomez drove by my house 🙀
# 29     I understand hailey Bieber because if my husba...
# 32     but then i always realize because SELENA GOMEZ...
# ...                                                  ...
# 11634  @SAFFAOnAirRadio is now playing, Selena Gomez,...
# 11635                     Go follow Selena Gomez on IG 😡
# 11638  @Ricius496 @endlessbonerz Selena Gomez has a m...
# 11642  I still can taste it and i hate it. \n\nPeople...
# 11644  Over the past few days, the alleged feud betwe...
#
#                                             preprocessed sentiment
# 5      social media diseas hailey bieber selena gomez...   Neutral
# 25     justin bieber amp selena gomez follow twitter ...   Neutral
# 28                               selena gomez drive hous   Neutral
# 29     understand hailey bieber husband ex selena gom...   Neutral
# 32             alway realiz selena gomez alway look good  Positive
# ...                                                  ...       ...
# 11634  saffaonairradio play selena gomez marshmello w...  Positive
# 11635                          go follow selena gomez ig   Neutral
# 11638  riciu endlessbonerz selena gomez medic issu st...   Neutral
# 11642            still tast hate peopl know selena gomez  Negative
# 11644  past day alleg feud selena gomez hailey bieber...  Negative
#
# [5206 rows x 5 columns]

# %%
data.to_excel('selenagomez_clean.xlsx')
