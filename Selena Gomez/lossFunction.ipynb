# %% [markdown]
# Melakukan import libraries yang dibutukan

# %%
import pandas as pd
import tensorflow as tf

# %%
data=pd.read_excel('./selenagomez_clean.xlsx')
del data['Unnamed: 0']
data
# Out:
#                           created_at         username  \
# 0     Thu Mar 02 23:59:30 +0000 2023        darkonsun
# 1     Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 2     Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 3     Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 4     Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...                              ...              ...
# 5201  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 5202  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 5203  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 5204  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 5205  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                    text  \
# 0     social media is a disease and this hailey bieb...
# 1     Justin Bieber &amp; Selena Gomez followed each...
# 2                      Selena Gomez drove by my house 🙀
# 3     I understand hailey Bieber because if my husba...
# 4     but then i always realize because SELENA GOMEZ...
# ...                                                 ...
# 5201  @SAFFAOnAirRadio is now playing, Selena Gomez,...
# 5202                     Go follow Selena Gomez on IG 😡
# 5203  @Ricius496 @endlessbonerz Selena Gomez has a m...
# 5204  I still can taste it and i hate it. \n\nPeople...
# 5205  Over the past few days, the alleged feud betwe...
#
#                                            preprocessed sentiment
# 0     social media diseas hailey bieber selena gomez...   Neutral
# 1     justin bieber amp selena gomez follow twitter ...   Neutral
# 2                               selena gomez drive hous   Neutral
# 3     understand hailey bieber husband ex selena gom...   Neutral
# 4             alway realiz selena gomez alway look good  Positive
# ...                                                 ...       ...
# 5201  saffaonairradio play selena gomez marshmello w...  Positive
# 5202                          go follow selena gomez ig   Neutral
# 5203  riciu endlessbonerz selena gomez medic issu st...   Neutral
# 5204            still tast hate peopl know selena gomez  Negative
# 5205  past day alleg feud selena gomez hailey bieber...  Negative
#
# [5206 rows x 5 columns]

# %%
data=data[['preprocessed','sentiment']]
data
# Out:
#                                            preprocessed sentiment
# 0     social media diseas hailey bieber selena gomez...   Neutral
# 1     justin bieber amp selena gomez follow twitter ...   Neutral
# 2                               selena gomez drive hous   Neutral
# 3     understand hailey bieber husband ex selena gom...   Neutral
# 4             alway realiz selena gomez alway look good  Positive
# ...                                                 ...       ...
# 5201  saffaonairradio play selena gomez marshmello w...  Positive
# 5202                          go follow selena gomez ig   Neutral
# 5203  riciu endlessbonerz selena gomez medic issu st...   Neutral
# 5204            still tast hate peopl know selena gomez  Negative
# 5205  past day alleg feud selena gomez hailey bieber...  Negative
#
# [5206 rows x 2 columns]

# %%
data.sentiment = pd.Categorical(pd.factorize(data.sentiment)[0])
data
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_26024\1650668707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.sentiment = pd.Categorical(pd.factorize(data.sentiment)[0])
#                                            preprocessed sentiment
# 0     social media diseas hailey bieber selena gomez...         0
# 1     justin bieber amp selena gomez follow twitter ...         0
# 2                               selena gomez drive hous         0
# 3     understand hailey bieber husband ex selena gom...         0
# 4             alway realiz selena gomez alway look good         1
# ...                                                 ...       ...
# 5201  saffaonairradio play selena gomez marshmello w...         1
# 5202                          go follow selena gomez ig         0
# 5203  riciu endlessbonerz selena gomez medic issu st...         0
# 5204            still tast hate peopl know selena gomez         2
# 5205  past day alleg feud selena gomez hailey bieber...         2
#
# [5206 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
#vectorizer = TfidfVectorizer()
##vectors = vectorizer.fit_transform(data['preprocessed'])
#feature_names = vectorizer.get_feature_names()
#dense = vectors.todense()
#denselist=dense.tolist()

# %%
max_len=15
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
tokenizer=Tokenizer(oov_token=oov_tok)
tokenizer.fit_on_texts(data['preprocessed'])

# %%
len(tokenizer.word_index)
# Out:
# 6995

# %%
sequences=tokenizer.texts_to_sequences(data['preprocessed'])
padded=pad_sequences(sequences=sequences,padding=padding_type,truncating=trunc_type,maxlen=max_len)
temp=0
kamus={}
for item in sequences:
    coba=len(item)
    if coba not in kamus:
        kamus[coba]=1
    else:
        kamus[coba]+=1

# %%
import matplotlib.pylab as plt

lists = sorted(kamus.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)
plt.show()

# %%
sequences=tokenizer.texts_to_sequences(data['preprocessed'])
padded=pad_sequences(sequences=sequences,padding=padding_type,truncating=trunc_type,maxlen=max_len)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(padded,data['sentiment'],test_size=0.1)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4685, 15), (521, 15), (4685,), (521,))

# %%
y_train= tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test= tf.keras.utils.to_categorical(y_test, num_classes=3)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4685, 15), (521, 15), (4685, 3), (521, 3))

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def createSimpleModel(loss):
    model=tf.keras.models.Sequential([
            tf.keras.layers.Embedding(len(tokenizer.word_index),16,input_length=max_len),
            tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences=True,activation='relu')),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(3, activation='softmax')
        ])
    model.compile(loss=loss,optimizer='rmsprop',metrics=['accuracy',f1_m])
    model.summary()
    return model

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    min_delta=0,
    patience=5,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#from scikeras.wrappers import KerasClassifier
#from sklearn.model_selection import KFold
#from sklearn.model_selection import cross_val_score
##estimator = KerasClassifier(build_fn=createSimpleModel(2), epochs=20, verbose=1,callbacks=[callback],validation_split=0.1)
#kfold = KFold(n_splits=5, shuffle=True)
#results = cross_val_score(estimator, x_train, y_train, cv=kfold,scoring='accuracy')
#results

# %%
loss=['categorical_crossentropy','mse']
result=[]
models=[]
for item in loss:
    print('Train model with {} optimizer'.format(item))
    model=createSimpleModel(loss=item)
    history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
    models.append(model)
    result.append(history)
# Out:
# Train model with categorical_crossentropy optimizer
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 15, 16)            111920
#
#  bidirectional (Bidirectiona  (None, 15, 128)          41472
#  l)
#
#  flatten (Flatten)           (None, 1920)              0
#
#  dense (Dense)               (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 20s 96ms/step - loss: 0.9233 - accuracy: 0.5415 - f1_m: 0.3771 - val_loss: 0.7518 - val_accuracy: 0.6610 - val_f1_m: 0.6251
# Epoch 2/20
# 132/132 [==============================] - 12s 89ms/step - loss: 0.5849 - accuracy: 0.7545 - f1_m: 0.7384 - val_loss: 0.6127 - val_accuracy: 0.7719 - val_f1_m: 0.7636
# Epoch 3/20
# 132/132 [==============================] - 13s 99ms/step - loss: 0.3813 - accuracy: 0.8657 - f1_m: 0.8618 - val_loss: 0.5884 - val_accuracy: 0.7868 - val_f1_m: 0.7799
# Epoch 4/20
# 132/132 [==============================] - 12s 92ms/step - loss: 0.2625 - accuracy: 0.9156 - f1_m: 0.9138 - val_loss: 0.4993 - val_accuracy: 0.8294 - val_f1_m: 0.8348
# Epoch 5/20
# 132/132 [==============================] - 11s 87ms/step - loss: 0.1809 - accuracy: 0.9469 - f1_m: 0.9460 - val_loss: 0.5305 - val_accuracy: 0.8209 - val_f1_m: 0.8276
# Epoch 6/20
# 132/132 [==============================] - 11s 85ms/step - loss: 0.1374 - accuracy: 0.9613 - f1_m: 0.9625 - val_loss: 0.6269 - val_accuracy: 0.8550 - val_f1_m: 0.8524
# Epoch 7/20
# 132/132 [==============================] - 11s 85ms/step - loss: 0.1103 - accuracy: 0.9685 - f1_m: 0.9694 - val_loss: 0.5801 - val_accuracy: 0.8507 - val_f1_m: 0.8528
# Epoch 8/20
# 132/132 [==============================] - 12s 89ms/step - loss: 0.0893 - accuracy: 0.9753 - f1_m: 0.9744 - val_loss: 0.6823 - val_accuracy: 0.8294 - val_f1_m: 0.8297
# Epoch 9/20
# 132/132 [==============================] - 13s 102ms/step - loss: 0.0869 - accuracy: 0.9798 - f1_m: 0.9798 - val_loss: 0.8382 - val_accuracy: 0.8507 - val_f1_m: 0.8568
# Epoch 10/20
# 132/132 [==============================] - 13s 100ms/step - loss: 0.0574 - accuracy: 0.9843 - f1_m: 0.9844 - val_loss: 0.8838 - val_accuracy: 0.8465 - val_f1_m: 0.8477
# Epoch 11/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9855 - f1_m: 0.9852Restoring model weights from the end of the best epoch: 6.
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0717 - accuracy: 0.9855 - f1_m: 0.9852 - val_loss: 1.0997 - val_accuracy: 0.8358 - val_f1_m: 0.8367
# Epoch 00011: early stopping
# Train model with mse optimizer
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 15, 16)            111920
#
#  bidirectional_1 (Bidirectio  (None, 15, 128)          41472
#  nal)
#
#  flatten_1 (Flatten)         (None, 1920)              0
#
#  dense_1 (Dense)             (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 14s 87ms/step - loss: 0.1802 - accuracy: 0.5484 - f1_m: 0.4047 - val_loss: 0.1561 - val_accuracy: 0.6546 - val_f1_m: 0.6288
# Epoch 2/20
# 132/132 [==============================] - 11s 85ms/step - loss: 0.1067 - accuracy: 0.7801 - f1_m: 0.7654 - val_loss: 0.1134 - val_accuracy: 0.7783 - val_f1_m: 0.7648
# Epoch 3/20
# 132/132 [==============================] - 12s 87ms/step - loss: 0.0678 - accuracy: 0.8669 - f1_m: 0.8648 - val_loss: 0.0971 - val_accuracy: 0.8017 - val_f1_m: 0.8005
# Epoch 4/20
# 132/132 [==============================] - 11s 86ms/step - loss: 0.0446 - accuracy: 0.9179 - f1_m: 0.9161 - val_loss: 0.0804 - val_accuracy: 0.8465 - val_f1_m: 0.8487
# Epoch 5/20
# 132/132 [==============================] - 11s 87ms/step - loss: 0.0321 - accuracy: 0.9421 - f1_m: 0.9425 - val_loss: 0.0832 - val_accuracy: 0.8443 - val_f1_m: 0.8379
# Epoch 6/20
# 132/132 [==============================] - 12s 87ms/step - loss: 0.0258 - accuracy: 0.9537 - f1_m: 0.9546 - val_loss: 0.0689 - val_accuracy: 0.8614 - val_f1_m: 0.8691
# Epoch 7/20
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0207 - accuracy: 0.9637 - f1_m: 0.9649 - val_loss: 0.1173 - val_accuracy: 0.7676 - val_f1_m: 0.7661
# Epoch 8/20
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0173 - accuracy: 0.9708 - f1_m: 0.9713 - val_loss: 0.0650 - val_accuracy: 0.8827 - val_f1_m: 0.8818
# Epoch 9/20
# 132/132 [==============================] - 12s 90ms/step - loss: 0.0156 - accuracy: 0.9751 - f1_m: 0.9754 - val_loss: 0.0700 - val_accuracy: 0.8721 - val_f1_m: 0.8723
# Epoch 10/20
# 132/132 [==============================] - 12s 92ms/step - loss: 0.0139 - accuracy: 0.9775 - f1_m: 0.9776 - val_loss: 0.0723 - val_accuracy: 0.8571 - val_f1_m: 0.8580
# Epoch 11/20
# 132/132 [==============================] - 13s 97ms/step - loss: 0.0133 - accuracy: 0.9775 - f1_m: 0.9775 - val_loss: 0.0689 - val_accuracy: 0.8657 - val_f1_m: 0.8669
# Epoch 12/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0116 - accuracy: 0.9791 - f1_m: 0.9793 - val_loss: 0.0888 - val_accuracy: 0.8252 - val_f1_m: 0.8199
# Epoch 13/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9824 - f1_m: 0.9823Restoring model weights from the end of the best epoch: 8.
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0107 - accuracy: 0.9824 - f1_m: 0.9823 - val_loss: 0.0803 - val_accuracy: 0.8380 - val_f1_m: 0.8383
# Epoch 00013: early stopping

# %%
def compareAccuracy(result,loss):
    plt.plot(result[0].history['accuracy'],color='b',label='{}'.format(loss[0]))
    plt.plot(result[1].history['accuracy'],color='g',label='{}'.format(loss[1]))
    plt.plot(result[0].history['val_accuracy'],color='r',label='Validasi {}'.format(loss[0]))
    plt.plot(result[1].history['val_accuracy'],color='c',label='Validasi {}'.format(loss[1]))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title("Akurasi Berdasarkan loss")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareAccuracy(result,loss)

# %%
def compareLoss(result,loss):
    plt.plot(result[0].history['loss'],color='b',label='{}'.format(loss[0]))
    plt.plot(result[1].history['loss'],color='g',label='{}'.format(loss[1]))
    plt.plot(result[0].history['val_loss'],color='r',label='Validasi {}'.format(loss[0]))
    plt.plot(result[1].history['val_loss'],color='c',label='Validasi {}'.format(loss[1]))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title("Loss Berdasarkan loss")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareLoss(result,loss)

# %%
def compareF1Score(result,loss):
    plt.plot(result[0].history['f1_m'],color='b',label='{}'.format(loss[0]))
    plt.plot(result[1].history['f1_m'],color='g',label='{}'.format(loss[1]))
    plt.plot(result[0].history['val_f1_m'],color='r',label='Validasi {}'.format(loss[0]))
    plt.plot(result[1].history['val_f1_m'],color='c',label='Validasi {}'.format(loss[1]))
    plt.xlabel("Nilai")
    plt.ylabel("Epochs")
    plt.title("F1 Score Berdasarkan loss")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareF1Score(result,loss)

# %%
for i in range(len(models)):
    temp=models[i].evaluate(x_test,y_test)
    print('model dengan loss {} mendapatkan matrix evaluasi '.format(loss[i]),temp)
# Out:
# 17/17 [==============================] - 0s 21ms/step - loss: 0.5277 - accuracy: 0.8656 - f1_m: 0.8704
# model dengan loss categorical_crossentropy mendapatkan matrix evaluasi  [0.5276795029640198, 0.8656429648399353, 0.8703746795654297]
# 17/17 [==============================] - 0s 20ms/step - loss: 0.0601 - accuracy: 0.8906 - f1_m: 0.8910
# model dengan loss mse mendapatkan matrix evaluasi  [0.06013413518667221, 0.890595018863678, 0.891018807888031]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
for item in models:
    predict=item.predict(x_test)
    confusion=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(predict,axis=1))
    display=ConfusionMatrixDisplay(confusion_matrix=confusion)
    display.plot()

# %%
model=createSimpleModel(1)
history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Skripsi\Selena Gomez\optimizer.ipynb Cell 25 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> model=createSimpleModel(1)
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
#
# d:\Skripsi\Selena Gomez\optimizer.ipynb Cell 25 in createSimpleModel(optimizer)
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> def createSimpleModel(optimizer):
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a>     model=tf.keras.models.Sequential([
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a>             tf.keras.layers.Embedding(len(tokenizer.word_index),16,input_length=max_len),
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a>             tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences=True,activation='relu')),
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a>             tf.keras.layers.Flatten(),
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=5'>6</a>             tf.keras.layers.Dense(3, activation='softmax')
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=6'>7</a>         ])
# ----> <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=7'>8</a>     model.compile(loss='categorical_crossentropy',optimizer=optimizer,metrics=['accuracy',f1_m])
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=8'>9</a>     model.summary()
#      <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/optimizer.ipynb#X33sZmlsZQ%3D%3D?line=9'>10</a>     return model
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers.py:132, in get(identifier)
#     130   return deserialize(config)
#     131 else:
# --> 132   raise ValueError(
#     133       'Could not interpret optimizer identifier: {}'.format(identifier))
#
# ValueError: Could not interpret optimizer identifier: 1

# %%
temp=model.evaluate(x_test,y_test)
temp
# Out:
# 17/17 [==============================] - 0s 11ms/step - loss: 0.1171 - accuracy: 0.8100 - f1_m: 0.8079
# [0.11711768805980682, 0.8099808096885681, 0.8078767657279968]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
predict=model.predict(x_test)
confusion=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(predict,axis=1))
display=ConfusionMatrixDisplay(confusion_matrix=confusion)
display.plot()

# %%
import matplotlib.pyplot as plt

def plot_graphs(history):
  figure, axis = plt.subplots(2, 2)
  figure.set_size_inches(18.5, 10.5, forward=True)

  axis[0,0].plot(history.history['accuracy'])
  axis[0,0].plot(history.history['val_accuracy'])
  axis[0,0].set_title('Accuracy')
  axis[0,0].legend(['accuracy','val_accuracy'])

  axis[0,1].plot(history.history['loss'])
  axis[0,1].plot(history.history['val_loss'])
  axis[0,1].set_title('Loss')
  axis[0,1].legend(['loss','val_loss'])

  axis[1,0].plot(history.history['f1_m'])
  axis[1,0].plot(history.history['val_f1_m'])
  axis[1,0].set_title('F1-Score')
  axis[1,0].legend(['f1_m','val_f1_m'])
  plt.show()

# %%
plot_graphs(history=history)

# %%
def createComplexModel(skenario):
    if skenario ==1:
        model=tf.keras.models.Sequential([
            tf.keras.layers.Embedding(len(tokenizer.word_index),128,input_length=max_len),
            tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2),
            tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2),
            tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(512,activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(3, activation='softmax')
        ])
        model.compile(loss='mse',optimizer=tf.keras.optimizers.RMSprop(),metrics=['accuracy',f1_m])
    else:
        model=tf.keras.models.Sequential([
        tf.keras.layers.Embedding(len(tokenizer.word_index),128,input_length=max_len),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512,activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(3,activation='softmax')
        ])
        model.compile(loss='mse',optimizer=tf.keras.optimizers.RMSprop(),metrics=['accuracy',f1_m])
    model.summary()
    return model

# %%
model=createComplexModel(2)
history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 15, 128)           895360
#
#  bidirectional_12 (Bidirecti  (None, 15, 256)          263168
#  onal)
#
#  bidirectional_13 (Bidirecti  (None, 15, 256)          394240
#  onal)
#
#  bidirectional_14 (Bidirecti  (None, 15, 256)          394240
#  onal)
#
#  flatten_10 (Flatten)        (None, 3840)              0
#
#  dense_18 (Dense)            (None, 512)               1966592
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_19 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 3,915,139
# Trainable params: 3,915,139
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 18s 55ms/step - loss: 0.8239 - accuracy: 0.6321 - f1_m: 0.5431 - val_loss: 0.5873 - val_accuracy: 0.7932 - val_f1_m: 0.7701
# Epoch 2/20
# 132/132 [==============================] - 5s 38ms/step - loss: 0.3966 - accuracy: 0.8653 - f1_m: 0.8647 - val_loss: 0.5742 - val_accuracy: 0.7996 - val_f1_m: 0.8013
# Epoch 3/20
# 132/132 [==============================] - 5s 37ms/step - loss: 0.2500 - accuracy: 0.9227 - f1_m: 0.9212 - val_loss: 0.3869 - val_accuracy: 0.8678 - val_f1_m: 0.8560
# Epoch 4/20
# 132/132 [==============================] - 5s 40ms/step - loss: 0.1565 - accuracy: 0.9542 - f1_m: 0.9539 - val_loss: 0.4261 - val_accuracy: 0.8401 - val_f1_m: 0.8421
# Epoch 5/20
# 132/132 [==============================] - 5s 38ms/step - loss: 0.1231 - accuracy: 0.9635 - f1_m: 0.9626 - val_loss: 0.4509 - val_accuracy: 0.8571 - val_f1_m: 0.8539
# Epoch 6/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.1005 - accuracy: 0.9720 - f1_m: 0.9722 - val_loss: 0.3989 - val_accuracy: 0.8699 - val_f1_m: 0.8620
# Epoch 7/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0775 - accuracy: 0.9763 - f1_m: 0.9766 - val_loss: 0.5164 - val_accuracy: 0.8785 - val_f1_m: 0.8808
# Epoch 8/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0611 - accuracy: 0.9817 - f1_m: 0.9817 - val_loss: 0.4865 - val_accuracy: 0.8785 - val_f1_m: 0.8807
# Epoch 9/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0544 - accuracy: 0.9848 - f1_m: 0.9846 - val_loss: 0.6683 - val_accuracy: 0.8507 - val_f1_m: 0.8520
# Epoch 10/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0439 - accuracy: 0.9879 - f1_m: 0.9878 - val_loss: 1.9408 - val_accuracy: 0.8721 - val_f1_m: 0.8714
# Epoch 11/20
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0470 - accuracy: 0.9886 - f1_m: 0.9887 - val_loss: 0.9230 - val_accuracy: 0.8763 - val_f1_m: 0.8794
# Epoch 12/20
# 131/132 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9921 - f1_m: 0.9921- ETA: 0s - loss: 0.0313 - accuracy: 0.9927 - Restoring model weights from the end of the best epoch: 7.
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0317 - accuracy: 0.9922 - f1_m: 0.9922 - val_loss: 1.1515 - val_accuracy: 0.8614 - val_f1_m: 0.8668
# Epoch 00012: early stopping

# %%
temp=model.evaluate(x_test,y_test)
temp
# Out:
# 17/17 [==============================] - 1s 32ms/step - loss: 0.5319 - accuracy: 0.8580 - f1_m: 0.8578
# [0.5319363474845886, 0.8579654693603516, 0.8578073382377625]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
predict=model.predict(x_test)
confusion=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(predict,axis=1))
display=ConfusionMatrixDisplay(confusion_matrix=confusion)
display.plot()

# %%
plot_graphs(history=history)
