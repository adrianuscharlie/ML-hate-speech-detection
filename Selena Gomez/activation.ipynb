# %% [markdown]
# Melakukan import libraries yang dibutukan

# %%
import pandas as pd
import tensorflow as tf

# %%
data=pd.read_excel('./selenagomez_clean_new_normalize.xlsx')
del data['Unnamed: 0']
data
# Out:
#                           created_at         username
# 0     Thu Mar 02 23:59:30 +0000 2023        darkonsun  \
# 1     Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 2     Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 3     Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 4     Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...                              ...              ...
# 5201  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 5202  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 5203  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 5204  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 5205  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                    text
# 0     social media is a disease and this hailey bieb...  \
# 1     Justin Bieber &amp; Selena Gomez followed each...
# 2                      Selena Gomez drove by my house 🙀
# 3     I understand hailey Bieber because if my husba...
# 4     but then i always realize because SELENA GOMEZ...
# ...                                                 ...
# 5201  @SAFFAOnAirRadio is now playing, Selena Gomez,...
# 5202                     Go follow Selena Gomez on IG 😡
# 5203  @Ricius496 @endlessbonerz Selena Gomez has a m...
# 5204  I still can taste it and i hate it. \n\nPeople...
# 5205  Over the past few days, the alleged feud betwe...
#
#                                            preprocessed sentiment
# 0     social media disease hailey bieber selena gome...   Neutral
# 1     justin bieber amp selena gomez follow twitter ...  Negative
# 2                         selena gomez drive miss house  Negative
# 3     understand hailey bieber miss husband ex selen...  Negative
# 4          always realize selena gomez always look good  Positive
# ...                                                 ...       ...
# 5201  play selena gomez marshmello wolves stream liv...  Positive
# 5202                   go follow selena gomez instagram   Neutral
# 5203            selena gomez medical issue still baddie   Neutral
# 5204          still taste hate people know selena gomez  Negative
# 5205  past days allege feud selena gomez hailey bieb...  Negative
#
# [5206 rows x 5 columns]

# %%
data=data[['preprocessed','sentiment']]
data
# Out:
#                                            preprocessed sentiment
# 0     social media disease hailey bieber selena gome...   Neutral
# 1     justin bieber amp selena gomez follow twitter ...  Negative
# 2                         selena gomez drive miss house  Negative
# 3     understand hailey bieber miss husband ex selen...  Negative
# 4          always realize selena gomez always look good  Positive
# ...                                                 ...       ...
# 5201  play selena gomez marshmello wolves stream liv...  Positive
# 5202                   go follow selena gomez instagram   Neutral
# 5203            selena gomez medical issue still baddie   Neutral
# 5204          still taste hate people know selena gomez  Negative
# 5205  past days allege feud selena gomez hailey bieb...  Negative
#
# [5206 rows x 2 columns]

# %%
data.sentiment = pd.Categorical(pd.factorize(data.sentiment)[0])
data
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21676\1650668707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.sentiment = pd.Categorical(pd.factorize(data.sentiment)[0])
#                                            preprocessed sentiment
# 0     social media disease hailey bieber selena gome...         0
# 1     justin bieber amp selena gomez follow twitter ...         1
# 2                         selena gomez drive miss house         1
# 3     understand hailey bieber miss husband ex selen...         1
# 4          always realize selena gomez always look good         2
# ...                                                 ...       ...
# 5201  play selena gomez marshmello wolves stream liv...         2
# 5202                   go follow selena gomez instagram         0
# 5203            selena gomez medical issue still baddie         0
# 5204          still taste hate people know selena gomez         1
# 5205  past days allege feud selena gomez hailey bieb...         1
#
# [5206 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
data['preprocessed']=data['preprocessed'].astype(str)
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
tokenizer=Tokenizer(oov_token=oov_tok)
tokenizer.fit_on_texts(data['preprocessed'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_21676\1608160908.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['preprocessed']=data['preprocessed'].astype(str)

# %%
len(tokenizer.word_index)
# Out:
# 5402

# %%
sequences=tokenizer.texts_to_sequences(data['preprocessed'])
padded=pad_sequences(sequences=sequences,padding=padding_type,truncating=trunc_type)
temp=0
kamus={}
for item in sequences:
    coba=len(item)
    if coba not in kamus:
        kamus[coba]=1
    else:
        kamus[coba]+=1

# %%
import matplotlib.pylab as plt

lists = sorted(kamus.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)
plt.show()

# %%
max_len=max(kamus)
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
tokenizer=Tokenizer(oov_token=oov_tok)
tokenizer.fit_on_texts(data['preprocessed'])

# %%
sequences=tokenizer.texts_to_sequences(data['preprocessed'])
padded=pad_sequences(sequences=sequences,padding=padding_type,truncating=trunc_type,maxlen=max_len)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(padded,data['sentiment'],test_size=0.1,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4685, 27), (521, 27), (4685,), (521,))

# %%
y_train= tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test= tf.keras.utils.to_categorical(y_test, num_classes=3)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4685, 27), (521, 27), (4685, 3), (521, 3))

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def createSimpleModel(activation):
    model=tf.keras.models.Sequential([
            tf.keras.layers.Embedding(len(tokenizer.word_index),16,input_length=max_len),
            tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences=True,activation=activation['hidden'])),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(3, activation=activation['output'])
        ])
    model.compile(loss='categorical_crossentropy',optimizer=tf.keras.optimizers.Adam(),metrics=['accuracy',f1_m])
    model.summary()
    return model

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    min_delta=0,
    patience=5,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#from scikeras.wrappers import KerasClassifier
#from sklearn.model_selection import KFold
#from sklearn.model_selection import cross_val_score
##estimator = KerasClassifier(build_fn=createSimpleModel(2), epochs=20, verbose=1,callbacks=[callback],validation_split=0.1)
#kfold = KFold(n_splits=5, shuffle=True)
#results = cross_val_score(estimator, x_train, y_train, cv=kfold,scoring='accuracy')
#results

# %%
activation=[{'hidden':'relu','output':'sigmoid'},{'hidden':'relu','output':'softmax',},
            {'hidden':'sigmoid','output':'sigmoid'},{'hidden':'sigmoid','output':'softmax'},
            {'hidden':'tanh','output':'sigmoid'},{'hidden':'tanh','output':'softmax'}]

models=[]
result=[]
for item in activation:
    print(item)
    model=createSimpleModel(activation=item)
    history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
    item['model']=(model)
    item['result']=history
    models.append(model)
    result.append(history)
# Out:
# {'hidden': 'relu', 'output': 'sigmoid'}
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 27, 16)            86432
#
#  bidirectional_6 (Bidirectio  (None, 27, 128)          41472
#  nal)
#
#  flatten_6 (Flatten)         (None, 3456)              0
#
#  dense_6 (Dense)             (None, 3)                 10371
#
# =================================================================
# Total params: 138,275
# Trainable params: 138,275
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 24s 165ms/step - loss: 0.9660 - accuracy: 0.5097 - f1_m: 0.5633 - val_loss: 0.8084 - val_accuracy: 0.6375 - val_f1_m: 0.6694
# Epoch 2/20
# 132/132 [==============================] - 22s 164ms/step - loss: 0.5887 - accuracy: 0.7740 - f1_m: 0.7194 - val_loss: 0.5425 - val_accuracy: 0.7953 - val_f1_m: 0.7548
# Epoch 3/20
# 132/132 [==============================] - 22s 166ms/step - loss: 0.2589 - accuracy: 0.9160 - f1_m: 0.8879 - val_loss: 0.4842 - val_accuracy: 0.8358 - val_f1_m: 0.8291
# Epoch 4/20
# 132/132 [==============================] - 22s 165ms/step - loss: 0.1243 - accuracy: 0.9639 - f1_m: 0.9568 - val_loss: 0.5849 - val_accuracy: 0.8294 - val_f1_m: 0.8222
# Epoch 5/20
# 132/132 [==============================] - 23s 172ms/step - loss: 0.0830 - accuracy: 0.9753 - f1_m: 0.9732 - val_loss: 0.8439 - val_accuracy: 0.8252 - val_f1_m: 0.8276
# Epoch 6/20
# 132/132 [==============================] - 22s 166ms/step - loss: 0.0655 - accuracy: 0.9836 - f1_m: 0.9823 - val_loss: 2.6221 - val_accuracy: 0.8294 - val_f1_m: 0.8223
# Epoch 7/20
# 132/132 [==============================] - 23s 173ms/step - loss: 0.0479 - accuracy: 0.9884 - f1_m: 0.9862 - val_loss: 0.7947 - val_accuracy: 0.8252 - val_f1_m: 0.8233
# Epoch 8/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9891 - f1_m: 0.9857Restoring model weights from the end of the best epoch: 3.
# 132/132 [==============================] - 22s 166ms/step - loss: 0.0429 - accuracy: 0.9891 - f1_m: 0.9857 - val_loss: 1.2310 - val_accuracy: 0.8316 - val_f1_m: 0.8190
# Epoch 00008: early stopping
# {'hidden': 'relu', 'output': 'softmax'}
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 27, 16)            86432
#
#  bidirectional_7 (Bidirectio  (None, 27, 128)          41472
#  nal)
#
#  flatten_7 (Flatten)         (None, 3456)              0
#
#  dense_7 (Dense)             (None, 3)                 10371
#
# =================================================================
# Total params: 138,275
# Trainable params: 138,275
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 24s 169ms/step - loss: 0.9288 - accuracy: 0.5138 - f1_m: 0.2971 - val_loss: 0.6928 - val_accuracy: 0.6972 - val_f1_m: 0.6758
# Epoch 2/20
# 132/132 [==============================] - 22s 168ms/step - loss: 0.4276 - accuracy: 0.8489 - f1_m: 0.8431 - val_loss: 0.4905 - val_accuracy: 0.8188 - val_f1_m: 0.8249
# Epoch 3/20
# 132/132 [==============================] - 23s 174ms/step - loss: 0.1933 - accuracy: 0.9438 - f1_m: 0.9437 - val_loss: 0.5372 - val_accuracy: 0.8038 - val_f1_m: 0.7996
# Epoch 4/20
# 132/132 [==============================] - 23s 171ms/step - loss: 0.1057 - accuracy: 0.9692 - f1_m: 0.9701 - val_loss: 0.4675 - val_accuracy: 0.8550 - val_f1_m: 0.8532
# Epoch 5/20
# 132/132 [==============================] - 23s 175ms/step - loss: 0.0673 - accuracy: 0.9829 - f1_m: 0.9832 - val_loss: 0.5991 - val_accuracy: 0.8337 - val_f1_m: 0.8378
# Epoch 6/20
# 132/132 [==============================] - 22s 167ms/step - loss: 0.0487 - accuracy: 0.9872 - f1_m: 0.9867 - val_loss: 0.6094 - val_accuracy: 0.8571 - val_f1_m: 0.8526
# Epoch 7/20
# 132/132 [==============================] - 22s 168ms/step - loss: 0.0531 - accuracy: 0.9855 - f1_m: 0.9860 - val_loss: 0.6619 - val_accuracy: 0.8507 - val_f1_m: 0.8481
# Epoch 8/20
# 132/132 [==============================] - 22s 167ms/step - loss: 0.0423 - accuracy: 0.9877 - f1_m: 0.9882 - val_loss: 0.6861 - val_accuracy: 0.8507 - val_f1_m: 0.8482
# Epoch 9/20
# 132/132 [==============================] - 22s 167ms/step - loss: 0.0351 - accuracy: 0.9905 - f1_m: 0.9902 - val_loss: 1.0574 - val_accuracy: 0.8124 - val_f1_m: 0.8087
# Epoch 10/20
# 132/132 [==============================] - 22s 166ms/step - loss: 0.0277 - accuracy: 0.9922 - f1_m: 0.9920 - val_loss: 1.0655 - val_accuracy: 0.8145 - val_f1_m: 0.8090
# Epoch 11/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9862 - f1_m: 0.9860Restoring model weights from the end of the best epoch: 6.
# 132/132 [==============================] - 22s 167ms/step - loss: 0.0440 - accuracy: 0.9862 - f1_m: 0.9860 - val_loss: 4.0499 - val_accuracy: 0.8337 - val_f1_m: 0.8309
# Epoch 00011: early stopping
# {'hidden': 'sigmoid', 'output': 'sigmoid'}
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 27, 16)            86432
#
#  bidirectional_8 (Bidirectio  (None, 27, 128)          41472
#  nal)
#
#  flatten_8 (Flatten)         (None, 3456)              0
#
#  dense_8 (Dense)             (None, 3)                 10371
#
# =================================================================
# Total params: 138,275
# Trainable params: 138,275
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 23s 157ms/step - loss: 1.1571 - accuracy: 0.3480 - f1_m: 0.4796 - val_loss: 1.0885 - val_accuracy: 0.4243 - val_f1_m: 0.4896
# Epoch 2/20
# 132/132 [==============================] - 21s 163ms/step - loss: 1.0739 - accuracy: 0.4004 - f1_m: 0.5128 - val_loss: 0.9837 - val_accuracy: 0.5181 - val_f1_m: 0.5615
# Epoch 3/20
# 132/132 [==============================] - 22s 166ms/step - loss: 0.9326 - accuracy: 0.5481 - f1_m: 0.5772 - val_loss: 0.7984 - val_accuracy: 0.6503 - val_f1_m: 0.6161
# Epoch 4/20
# 132/132 [==============================] - 21s 155ms/step - loss: 0.6334 - accuracy: 0.7412 - f1_m: 0.6809 - val_loss: 0.6011 - val_accuracy: 0.7548 - val_f1_m: 0.6906
# Epoch 5/20
# 132/132 [==============================] - 22s 163ms/step - loss: 0.4079 - accuracy: 0.8529 - f1_m: 0.7518 - val_loss: 0.4982 - val_accuracy: 0.7996 - val_f1_m: 0.7296
# Epoch 6/20
# 132/132 [==============================] - 23s 172ms/step - loss: 0.2700 - accuracy: 0.9120 - f1_m: 0.7933 - val_loss: 0.5007 - val_accuracy: 0.8316 - val_f1_m: 0.7534
# Epoch 7/20
# 132/132 [==============================] - 24s 182ms/step - loss: 0.1752 - accuracy: 0.9478 - f1_m: 0.8201 - val_loss: 0.5098 - val_accuracy: 0.8465 - val_f1_m: 0.7418
# Epoch 8/20
# 132/132 [==============================] - 24s 181ms/step - loss: 0.1250 - accuracy: 0.9642 - f1_m: 0.8294 - val_loss: 0.5145 - val_accuracy: 0.8550 - val_f1_m: 0.7669
# Epoch 9/20
# 132/132 [==============================] - 24s 181ms/step - loss: 0.0911 - accuracy: 0.9775 - f1_m: 0.8407 - val_loss: 0.5772 - val_accuracy: 0.8380 - val_f1_m: 0.7254
# Epoch 10/20
# 132/132 [==============================] - 23s 174ms/step - loss: 0.0722 - accuracy: 0.9834 - f1_m: 0.8425 - val_loss: 0.6726 - val_accuracy: 0.8337 - val_f1_m: 0.7809
# Epoch 11/20
# 132/132 [==============================] - 25s 186ms/step - loss: 0.0568 - accuracy: 0.9870 - f1_m: 0.8520 - val_loss: 0.6201 - val_accuracy: 0.8486 - val_f1_m: 0.7590
# Epoch 12/20
# 132/132 [==============================] - 23s 176ms/step - loss: 0.0528 - accuracy: 0.9867 - f1_m: 0.8574 - val_loss: 0.6598 - val_accuracy: 0.8486 - val_f1_m: 0.7590
# Epoch 13/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9912 - f1_m: 0.8659Restoring model weights from the end of the best epoch: 8.
# 132/132 [==============================] - 23s 176ms/step - loss: 0.0365 - accuracy: 0.9912 - f1_m: 0.8659 - val_loss: 0.6984 - val_accuracy: 0.8486 - val_f1_m: 0.7387
# Epoch 00013: early stopping
# {'hidden': 'sigmoid', 'output': 'softmax'}
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 27, 16)            86432
#
#  bidirectional_9 (Bidirectio  (None, 27, 128)          41472
#  nal)
#
#  flatten_9 (Flatten)         (None, 3456)              0
#
#  dense_9 (Dense)             (None, 3)                 10371
#
# =================================================================
# Total params: 138,275
# Trainable params: 138,275
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 28s 179ms/step - loss: 1.1350 - accuracy: 0.3489 - f1_m: 0.0530 - val_loss: 1.1184 - val_accuracy: 0.3198 - val_f1_m: 0.0000e+00
# Epoch 2/20
# 132/132 [==============================] - 22s 169ms/step - loss: 1.0790 - accuracy: 0.3980 - f1_m: 0.1748 - val_loss: 0.9713 - val_accuracy: 0.5096 - val_f1_m: 0.2184
# Epoch 3/20
# 132/132 [==============================] - 23s 175ms/step - loss: 0.9616 - accuracy: 0.5230 - f1_m: 0.3726 - val_loss: 0.9620 - val_accuracy: 0.4840 - val_f1_m: 0.4489
# Epoch 4/20
# 132/132 [==============================] - 24s 180ms/step - loss: 0.7635 - accuracy: 0.6537 - f1_m: 0.6032 - val_loss: 0.7680 - val_accuracy: 0.6418 - val_f1_m: 0.6029
# Epoch 5/20
# 132/132 [==============================] - 25s 189ms/step - loss: 0.5160 - accuracy: 0.8072 - f1_m: 0.7967 - val_loss: 0.6366 - val_accuracy: 0.7399 - val_f1_m: 0.7309
# Epoch 6/20
# 132/132 [==============================] - 24s 183ms/step - loss: 0.3301 - accuracy: 0.8835 - f1_m: 0.8846 - val_loss: 0.5479 - val_accuracy: 0.7889 - val_f1_m: 0.7838
# Epoch 7/20
# 132/132 [==============================] - 23s 172ms/step - loss: 0.2236 - accuracy: 0.9315 - f1_m: 0.9302 - val_loss: 0.5729 - val_accuracy: 0.8038 - val_f1_m: 0.7993
# Epoch 8/20
# 132/132 [==============================] - 24s 179ms/step - loss: 0.1504 - accuracy: 0.9566 - f1_m: 0.9568 - val_loss: 0.5593 - val_accuracy: 0.8273 - val_f1_m: 0.8249
# Epoch 9/20
# 132/132 [==============================] - 24s 181ms/step - loss: 0.1216 - accuracy: 0.9675 - f1_m: 0.9682 - val_loss: 0.5835 - val_accuracy: 0.8188 - val_f1_m: 0.8173
# Epoch 10/20
# 132/132 [==============================] - 21s 162ms/step - loss: 0.0887 - accuracy: 0.9796 - f1_m: 0.9798 - val_loss: 0.6922 - val_accuracy: 0.7974 - val_f1_m: 0.7943
# Epoch 11/20
# 132/132 [==============================] - 21s 163ms/step - loss: 0.0744 - accuracy: 0.9836 - f1_m: 0.9834 - val_loss: 0.6472 - val_accuracy: 0.8316 - val_f1_m: 0.8281
# Epoch 12/20
# 132/132 [==============================] - 21s 162ms/step - loss: 0.0571 - accuracy: 0.9862 - f1_m: 0.9864 - val_loss: 0.6658 - val_accuracy: 0.8380 - val_f1_m: 0.8319
# Epoch 13/20
# 132/132 [==============================] - 21s 161ms/step - loss: 0.0473 - accuracy: 0.9907 - f1_m: 0.9905 - val_loss: 0.6759 - val_accuracy: 0.8316 - val_f1_m: 0.8322
# Epoch 14/20
# 132/132 [==============================] - 22s 170ms/step - loss: 0.0377 - accuracy: 0.9912 - f1_m: 0.9915 - val_loss: 0.7030 - val_accuracy: 0.8294 - val_f1_m: 0.8263
# Epoch 15/20
# 132/132 [==============================] - 22s 169ms/step - loss: 0.0397 - accuracy: 0.9905 - f1_m: 0.9906 - val_loss: 0.8625 - val_accuracy: 0.8081 - val_f1_m: 0.8045
# Epoch 16/20
# 132/132 [==============================] - 22s 163ms/step - loss: 0.0310 - accuracy: 0.9924 - f1_m: 0.9924 - val_loss: 0.7770 - val_accuracy: 0.8252 - val_f1_m: 0.8258
# Epoch 17/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9943 - f1_m: 0.9944- ETA: 6s - loss: 0.02Restoring model weights from the end of the best epoch: 12.
# 132/132 [==============================] - 23s 173ms/step - loss: 0.0256 - accuracy: 0.9943 - f1_m: 0.9944 - val_loss: 0.9021 - val_accuracy: 0.8273 - val_f1_m: 0.8258
# Epoch 00017: early stopping
# {'hidden': 'tanh', 'output': 'sigmoid'}
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 27, 16)            86432
#
#  bidirectional_10 (Bidirecti  (None, 27, 128)          41472
#  onal)
#
#  flatten_10 (Flatten)        (None, 3456)              0
#
#  dense_10 (Dense)            (None, 3)                 10371
#
# =================================================================
# Total params: 138,275
# Trainable params: 138,275
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 6s 23ms/step - loss: 0.8770 - accuracy: 0.5534 - f1_m: 0.5815 - val_loss: 0.6731 - val_accuracy: 0.7079 - val_f1_m: 0.6874
# Epoch 2/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.3697 - accuracy: 0.8724 - f1_m: 0.8265 - val_loss: 0.5904 - val_accuracy: 0.8145 - val_f1_m: 0.7769
# Epoch 3/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.1560 - accuracy: 0.9540 - f1_m: 0.9137 - val_loss: 0.5758 - val_accuracy: 0.8230 - val_f1_m: 0.7936
# Epoch 4/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0927 - accuracy: 0.9763 - f1_m: 0.9433 - val_loss: 0.6891 - val_accuracy: 0.8038 - val_f1_m: 0.7982
# Epoch 5/20
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0639 - accuracy: 0.9829 - f1_m: 0.9578 - val_loss: 0.7473 - val_accuracy: 0.8124 - val_f1_m: 0.7997
# Epoch 6/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0573 - accuracy: 0.9846 - f1_m: 0.9591 - val_loss: 0.7254 - val_accuracy: 0.8316 - val_f1_m: 0.8181
# Epoch 7/20
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0457 - accuracy: 0.9874 - f1_m: 0.9637 - val_loss: 0.7275 - val_accuracy: 0.8166 - val_f1_m: 0.7835
# Epoch 8/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0405 - accuracy: 0.9889 - f1_m: 0.9619 - val_loss: 0.7301 - val_accuracy: 0.8230 - val_f1_m: 0.8108
# Epoch 9/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0329 - accuracy: 0.9903 - f1_m: 0.9726 - val_loss: 0.9603 - val_accuracy: 0.8316 - val_f1_m: 0.8003
# Epoch 10/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0258 - accuracy: 0.9938 - f1_m: 0.9580 - val_loss: 0.9177 - val_accuracy: 0.8252 - val_f1_m: 0.7958
# Epoch 11/20
# 131/132 [============================>.] - ETA: 0s - loss: 0.0273 - accuracy: 0.9928 - f1_m: 0.9420Restoring model weights from the end of the best epoch: 6.
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0271 - accuracy: 0.9929 - f1_m: 0.9421 - val_loss: 1.0824 - val_accuracy: 0.8145 - val_f1_m: 0.7803
# Epoch 00011: early stopping
# {'hidden': 'tanh', 'output': 'softmax'}
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_11 (Embedding)    (None, 27, 16)            86432
#
#  bidirectional_11 (Bidirecti  (None, 27, 128)          41472
#  onal)
#
#  flatten_11 (Flatten)        (None, 3456)              0
#
#  dense_11 (Dense)            (None, 3)                 10371
#
# =================================================================
# Total params: 138,275
# Trainable params: 138,275
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 6s 22ms/step - loss: 0.9227 - accuracy: 0.5249 - f1_m: 0.3235 - val_loss: 0.6817 - val_accuracy: 0.6972 - val_f1_m: 0.6882
# Epoch 2/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.4332 - accuracy: 0.8408 - f1_m: 0.8420 - val_loss: 0.5614 - val_accuracy: 0.7655 - val_f1_m: 0.7521
# Epoch 3/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.1773 - accuracy: 0.9473 - f1_m: 0.9482 - val_loss: 0.5079 - val_accuracy: 0.8209 - val_f1_m: 0.8179
# Epoch 4/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.1159 - accuracy: 0.9677 - f1_m: 0.9678 - val_loss: 0.5608 - val_accuracy: 0.8166 - val_f1_m: 0.8207
# Epoch 5/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0694 - accuracy: 0.9822 - f1_m: 0.9819 - val_loss: 0.6046 - val_accuracy: 0.8252 - val_f1_m: 0.8231
# Epoch 6/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0466 - accuracy: 0.9881 - f1_m: 0.9878 - val_loss: 0.8616 - val_accuracy: 0.8166 - val_f1_m: 0.8173
# Epoch 7/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0476 - accuracy: 0.9879 - f1_m: 0.9883 - val_loss: 0.7825 - val_accuracy: 0.8294 - val_f1_m: 0.8292
# Epoch 8/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0442 - accuracy: 0.9867 - f1_m: 0.9867 - val_loss: 0.9287 - val_accuracy: 0.8038 - val_f1_m: 0.8042
# Epoch 9/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0373 - accuracy: 0.9917 - f1_m: 0.9916 - val_loss: 0.9019 - val_accuracy: 0.8188 - val_f1_m: 0.8156
# Epoch 10/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0313 - accuracy: 0.9915 - f1_m: 0.9914 - val_loss: 0.8744 - val_accuracy: 0.8166 - val_f1_m: 0.8178
# Epoch 11/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0249 - accuracy: 0.9936 - f1_m: 0.9935 - val_loss: 0.9684 - val_accuracy: 0.8145 - val_f1_m: 0.8126
# Epoch 12/20
# 130/132 [============================>.] - ETA: 0s - loss: 0.0181 - accuracy: 0.9954 - f1_m: 0.9951Restoring model weights from the end of the best epoch: 7.
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0194 - accuracy: 0.9953 - f1_m: 0.9949 - val_loss: 1.1232 - val_accuracy: 0.7996 - val_f1_m: 0.8035
# Epoch 00012: early stopping

# %%
def compareAccuracy(result,activation):
    plt.plot(result[0].history['accuracy'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['accuracy'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['accuracy'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['accuracy'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['accuracy'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['accuracy'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title("Akurasi Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareAccuracy(result,activation)
def compareValidationAccuracy(result,activation):
    plt.plot(result[0].history['val_accuracy'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['val_accuracy'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['val_accuracy'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['val_accuracy'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['val_accuracy'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['val_accuracy'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title("Validasi Akurasi Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareValidationAccuracy(result,activation)

# %%
def compareLoss(result,activation):
    plt.plot(result[0].history['loss'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['loss'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['loss'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['loss'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['loss'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['loss'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title("Loss Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareLoss(result,activation)
def compareValidationLoss(result,activation):
    plt.plot(result[0].history['val_loss'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['val_loss'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['val_loss'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['val_loss'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['val_loss'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['val_loss'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title("Validasi Loss Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareValidationLoss(result,activation)

# %%
def compareF1Score(result,activation):
    plt.plot(result[0].history['f1_m'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['f1_m'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['f1_m'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['f1_m'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['f1_m'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['f1_m'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title(" F1 Score Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareF1Score(result,activation)
def compareValidationF1Score(result,activation):
    plt.plot(result[0].history['val_f1_m'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['val_f1_m'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['val_f1_m'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['val_f1_m'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['val_f1_m'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['val_f1_m'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title(" Validasi F1 Score Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareValidationF1Score(result,activation)

# %%
for i in range(6):
    temp=models[i].evaluate(x_test,y_test)
    print("Model dengan hidden layer {} dan output layer {} dengan matrix evaluasi".format(activation[i]['hidden'],activation[i]['output']),temp)
# Out:
# 17/17 [==============================] - 1s 31ms/step - loss: 0.5076 - accuracy: 0.8119 - f1_m: 0.8071
# Model dengan hidden layer relu dan output layer sigmoid dengan matrix evaluasi [0.5075923204421997, 0.8119001984596252, 0.8070864081382751]
# 17/17 [==============================] - 1s 35ms/step - loss: 0.7424 - accuracy: 0.8369 - f1_m: 0.8346
# Model dengan hidden layer relu dan output layer softmax dengan matrix evaluasi [0.742386519908905, 0.8368521928787231, 0.8345750570297241]
# 17/17 [==============================] - 1s 30ms/step - loss: 0.5811 - accuracy: 0.8349 - f1_m: 0.7514
# Model dengan hidden layer sigmoid dan output layer sigmoid dengan matrix evaluasi [0.581088662147522, 0.834932804107666, 0.7514498829841614]
# 17/17 [==============================] - 0s 26ms/step - loss: 0.7925 - accuracy: 0.8004 - f1_m: 0.8082
# Model dengan hidden layer sigmoid dan output layer softmax dengan matrix evaluasi [0.7925065755844116, 0.8003838658332825, 0.8082351684570312]
# 17/17 [==============================] - 0s 11ms/step - loss: 0.7918 - accuracy: 0.8023 - f1_m: 0.8021
# Model dengan hidden layer tanh dan output layer sigmoid dengan matrix evaluasi [0.7918348908424377, 0.8023032546043396, 0.8021374940872192]
# 17/17 [==============================] - 0s 11ms/step - loss: 0.8321 - accuracy: 0.8081 - f1_m: 0.8123
# Model dengan hidden layer tanh dan output layer softmax dengan matrix evaluasi [0.8320705890655518, 0.808061420917511, 0.8122665286064148]

# %%
for act in activation:
    template=f"./Model/Simple/Activation/{act['hidden']}_{act['output']}.h5"
    act['model'].save(template)
