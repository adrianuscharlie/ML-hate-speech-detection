# %% [markdown]
# Melakukan import libraries yang dibutukan

# %%
import pandas as pd
import tensorflow as tf

# %%
data=pd.read_excel('./selenagomez_clean.xlsx')
del data['Unnamed: 0']
data
# Out:
#                           created_at         username  \
# 0     Thu Mar 02 23:59:30 +0000 2023        darkonsun
# 1     Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 2     Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 3     Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 4     Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...                              ...              ...
# 5201  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 5202  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 5203  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 5204  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 5205  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                    text  \
# 0     social media is a disease and this hailey bieb...
# 1     Justin Bieber &amp; Selena Gomez followed each...
# 2                      Selena Gomez drove by my house 🙀
# 3     I understand hailey Bieber because if my husba...
# 4     but then i always realize because SELENA GOMEZ...
# ...                                                 ...
# 5201  @SAFFAOnAirRadio is now playing, Selena Gomez,...
# 5202                     Go follow Selena Gomez on IG 😡
# 5203  @Ricius496 @endlessbonerz Selena Gomez has a m...
# 5204  I still can taste it and i hate it. \n\nPeople...
# 5205  Over the past few days, the alleged feud betwe...
#
#                                            preprocessed sentiment
# 0     social media diseas hailey bieber selena gomez...   Neutral
# 1     justin bieber amp selena gomez follow twitter ...   Neutral
# 2                               selena gomez drive hous   Neutral
# 3     understand hailey bieber husband ex selena gom...   Neutral
# 4             alway realiz selena gomez alway look good  Positive
# ...                                                 ...       ...
# 5201  saffaonairradio play selena gomez marshmello w...  Positive
# 5202                          go follow selena gomez ig   Neutral
# 5203  riciu endlessbonerz selena gomez medic issu st...   Neutral
# 5204            still tast hate peopl know selena gomez  Negative
# 5205  past day alleg feud selena gomez hailey bieber...  Negative
#
# [5206 rows x 5 columns]

# %%
data=data[['preprocessed','sentiment']]
data
# Out:
#                                            preprocessed sentiment
# 0     social media diseas hailey bieber selena gomez...   Neutral
# 1     justin bieber amp selena gomez follow twitter ...   Neutral
# 2                               selena gomez drive hous   Neutral
# 3     understand hailey bieber husband ex selena gom...   Neutral
# 4             alway realiz selena gomez alway look good  Positive
# ...                                                 ...       ...
# 5201  saffaonairradio play selena gomez marshmello w...  Positive
# 5202                          go follow selena gomez ig   Neutral
# 5203  riciu endlessbonerz selena gomez medic issu st...   Neutral
# 5204            still tast hate peopl know selena gomez  Negative
# 5205  past day alleg feud selena gomez hailey bieber...  Negative
#
# [5206 rows x 2 columns]

# %%
data.sentiment = pd.Categorical(pd.factorize(data.sentiment)[0])
data
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_14296\1650668707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.sentiment = pd.Categorical(pd.factorize(data.sentiment)[0])
#                                            preprocessed sentiment
# 0     social media diseas hailey bieber selena gomez...         0
# 1     justin bieber amp selena gomez follow twitter ...         0
# 2                               selena gomez drive hous         0
# 3     understand hailey bieber husband ex selena gom...         0
# 4             alway realiz selena gomez alway look good         1
# ...                                                 ...       ...
# 5201  saffaonairradio play selena gomez marshmello w...         1
# 5202                          go follow selena gomez ig         0
# 5203  riciu endlessbonerz selena gomez medic issu st...         0
# 5204            still tast hate peopl know selena gomez         2
# 5205  past day alleg feud selena gomez hailey bieber...         2
#
# [5206 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
#vectorizer = TfidfVectorizer()
##vectors = vectorizer.fit_transform(data['preprocessed'])
#feature_names = vectorizer.get_feature_names()
#dense = vectors.todense()
#denselist=dense.tolist()

# %%
max_len=15
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
tokenizer=Tokenizer(oov_token=oov_tok)
tokenizer.fit_on_texts(data['preprocessed'])

# %%
len(tokenizer.word_index)
# Out:
# 6995

# %%
sequences=tokenizer.texts_to_sequences(data['preprocessed'])
padded=pad_sequences(sequences=sequences,padding=padding_type,truncating=trunc_type,maxlen=max_len)
temp=0
kamus={}
for item in sequences:
    coba=len(item)
    if coba not in kamus:
        kamus[coba]=1
    else:
        kamus[coba]+=1

# %%
import matplotlib.pylab as plt

lists = sorted(kamus.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)
plt.show()

# %%
sequences=tokenizer.texts_to_sequences(data['preprocessed'])
padded=pad_sequences(sequences=sequences,padding=padding_type,truncating=trunc_type,maxlen=max_len)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(padded,data['sentiment'],test_size=0.1)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4685, 15), (521, 15), (4685,), (521,))

# %%
y_train= tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test= tf.keras.utils.to_categorical(y_test, num_classes=3)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4685, 15), (521, 15), (4685, 3), (521, 3))

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def createSimpleModel(activation):
    model=tf.keras.models.Sequential([
            tf.keras.layers.Embedding(len(tokenizer.word_index),16,input_length=max_len),
            tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences=True,activation=activation['hidden'])),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(3, activation=activation['output'])
        ])
    model.compile(loss='categorical_crossentropy',optimizer=tf.keras.optimizers.Adam(),metrics=['accuracy',f1_m])
    model.summary()
    return model

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    min_delta=0,
    patience=5,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#from scikeras.wrappers import KerasClassifier
#from sklearn.model_selection import KFold
#from sklearn.model_selection import cross_val_score
##estimator = KerasClassifier(build_fn=createSimpleModel(2), epochs=20, verbose=1,callbacks=[callback],validation_split=0.1)
#kfold = KFold(n_splits=5, shuffle=True)
#results = cross_val_score(estimator, x_train, y_train, cv=kfold,scoring='accuracy')
#results

# %%
activation=[{'hidden':'relu','output':'sigmoid'},{'hidden':'relu','output':'softmax',},
            {'hidden':'sigmoid','output':'sigmoid'},{'hidden':'sigmoid','output':'softmax'},
            {'hidden':'tanh','output':'sigmoid'},{'hidden':'tanh','output':'softmax'}]
result=[]
models=[]
for item in activation:
    print(item)
    model=createSimpleModel(activation=item)
    history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
    models.append(model)
    result.append(history)
# Out:
# {'hidden': 'relu', 'output': 'sigmoid'}
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 15, 16)            111920
#
#  bidirectional_6 (Bidirectio  (None, 15, 128)          41472
#  nal)
#
#  flatten_6 (Flatten)         (None, 1920)              0
#
#  dense_6 (Dense)             (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 16s 103ms/step - loss: 0.9424 - accuracy: 0.5268 - f1_m: 0.5654 - val_loss: 0.6244 - val_accuracy: 0.7676 - val_f1_m: 0.7432
# Epoch 2/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.3745 - accuracy: 0.8755 - f1_m: 0.8577 - val_loss: 0.3883 - val_accuracy: 0.8507 - val_f1_m: 0.8602
# Epoch 3/20
# 132/132 [==============================] - 13s 99ms/step - loss: 0.1376 - accuracy: 0.9583 - f1_m: 0.9483 - val_loss: 0.5264 - val_accuracy: 0.8699 - val_f1_m: 0.8621
# Epoch 4/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0917 - accuracy: 0.9765 - f1_m: 0.9696 - val_loss: 0.4259 - val_accuracy: 0.8486 - val_f1_m: 0.8529
# Epoch 5/20
# 132/132 [==============================] - 13s 98ms/step - loss: 0.0458 - accuracy: 0.9905 - f1_m: 0.9859 - val_loss: 0.4205 - val_accuracy: 0.8550 - val_f1_m: 0.8608
# Epoch 6/20
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0308 - accuracy: 0.9926 - f1_m: 0.9882 - val_loss: 0.7928 - val_accuracy: 0.8273 - val_f1_m: 0.8215
# Epoch 7/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0232 - accuracy: 0.9941 - f1_m: 0.9909 - val_loss: 0.6065 - val_accuracy: 0.8635 - val_f1_m: 0.8532
# Epoch 8/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9964 - f1_m: 0.9945Restoring model weights from the end of the best epoch: 3.
# 132/132 [==============================] - 12s 92ms/step - loss: 0.0156 - accuracy: 0.9964 - f1_m: 0.9945 - val_loss: 0.5848 - val_accuracy: 0.8635 - val_f1_m: 0.8616
# Epoch 00008: early stopping
# {'hidden': 'relu', 'output': 'softmax'}
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 15, 16)            111920
#
#  bidirectional_7 (Bidirectio  (None, 15, 128)          41472
#  nal)
#
#  flatten_7 (Flatten)         (None, 1920)              0
#
#  dense_7 (Dense)             (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 15s 96ms/step - loss: 0.9103 - accuracy: 0.5467 - f1_m: 0.3612 - val_loss: 0.6660 - val_accuracy: 0.7122 - val_f1_m: 0.6920
# Epoch 2/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.4346 - accuracy: 0.8458 - f1_m: 0.8336 - val_loss: 0.5482 - val_accuracy: 0.7974 - val_f1_m: 0.8023
# Epoch 3/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.1704 - accuracy: 0.9514 - f1_m: 0.9490 - val_loss: 0.4882 - val_accuracy: 0.8507 - val_f1_m: 0.8470
# Epoch 4/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.0902 - accuracy: 0.9753 - f1_m: 0.9756 - val_loss: 0.4621 - val_accuracy: 0.8507 - val_f1_m: 0.8573
# Epoch 5/20
# 132/132 [==============================] - 13s 95ms/step - loss: 0.0545 - accuracy: 0.9865 - f1_m: 0.9866 - val_loss: 0.8393 - val_accuracy: 0.8571 - val_f1_m: 0.8560
# Epoch 6/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.0429 - accuracy: 0.9900 - f1_m: 0.9900 - val_loss: 0.6503 - val_accuracy: 0.8614 - val_f1_m: 0.8651
# Epoch 7/20
# 132/132 [==============================] - 13s 95ms/step - loss: 0.0269 - accuracy: 0.9929 - f1_m: 0.9928 - val_loss: 0.4733 - val_accuracy: 0.8657 - val_f1_m: 0.8668
# Epoch 8/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0340 - accuracy: 0.9905 - f1_m: 0.9907 - val_loss: 1.2508 - val_accuracy: 0.8230 - val_f1_m: 0.8189
# Epoch 9/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0596 - accuracy: 0.9896 - f1_m: 0.9893 - val_loss: 0.7313 - val_accuracy: 0.8635 - val_f1_m: 0.8646
# Epoch 10/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.0372 - accuracy: 0.9922 - f1_m: 0.9918 - val_loss: 0.5497 - val_accuracy: 0.8721 - val_f1_m: 0.8686
# Epoch 11/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0233 - accuracy: 0.9950 - f1_m: 0.9947 - val_loss: 0.8121 - val_accuracy: 0.8422 - val_f1_m: 0.8440
# Epoch 12/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0117 - accuracy: 0.9979 - f1_m: 0.9979 - val_loss: 0.8146 - val_accuracy: 0.8571 - val_f1_m: 0.8581
# Epoch 13/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0113 - accuracy: 0.9974 - f1_m: 0.9973 - val_loss: 1.0108 - val_accuracy: 0.8507 - val_f1_m: 0.8497
# Epoch 14/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.0079 - accuracy: 0.9981 - f1_m: 0.9979 - val_loss: 0.7980 - val_accuracy: 0.8550 - val_f1_m: 0.8554
# Epoch 15/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9969 - f1_m: 0.9970Restoring model weights from the end of the best epoch: 10.
# 132/132 [==============================] - 12s 94ms/step - loss: 0.0096 - accuracy: 0.9969 - f1_m: 0.9970 - val_loss: 1.1589 - val_accuracy: 0.8294 - val_f1_m: 0.8316
# Epoch 00015: early stopping
# {'hidden': 'sigmoid', 'output': 'sigmoid'}
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 15, 16)            111920
#
#  bidirectional_8 (Bidirectio  (None, 15, 128)          41472
#  nal)
#
#  flatten_8 (Flatten)         (None, 1920)              0
#
#  dense_8 (Dense)             (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 15s 97ms/step - loss: 1.0961 - accuracy: 0.4167 - f1_m: 0.5045 - val_loss: 1.0758 - val_accuracy: 0.3966 - val_f1_m: 0.5000
# Epoch 2/20
# 132/132 [==============================] - 12s 93ms/step - loss: 1.0054 - accuracy: 0.4991 - f1_m: 0.5349 - val_loss: 0.9596 - val_accuracy: 0.5309 - val_f1_m: 0.5782
# Epoch 3/20
# 132/132 [==============================] - 13s 95ms/step - loss: 0.7913 - accuracy: 0.6528 - f1_m: 0.6126 - val_loss: 0.7066 - val_accuracy: 0.7313 - val_f1_m: 0.6253
# Epoch 4/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.5209 - accuracy: 0.7932 - f1_m: 0.7006 - val_loss: 0.5844 - val_accuracy: 0.7719 - val_f1_m: 0.6797
# Epoch 5/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.3124 - accuracy: 0.8885 - f1_m: 0.7578 - val_loss: 0.4976 - val_accuracy: 0.8145 - val_f1_m: 0.7292
# Epoch 6/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.1747 - accuracy: 0.9504 - f1_m: 0.8041 - val_loss: 0.5838 - val_accuracy: 0.8145 - val_f1_m: 0.7100
# Epoch 7/20
# 132/132 [==============================] - 13s 101ms/step - loss: 0.1124 - accuracy: 0.9708 - f1_m: 0.8386 - val_loss: 0.5316 - val_accuracy: 0.8422 - val_f1_m: 0.7543
# Epoch 8/20
# 132/132 [==============================] - 14s 105ms/step - loss: 0.0706 - accuracy: 0.9824 - f1_m: 0.8729 - val_loss: 0.6092 - val_accuracy: 0.8252 - val_f1_m: 0.7365
# Epoch 9/20
# 132/132 [==============================] - 14s 104ms/step - loss: 0.0500 - accuracy: 0.9879 - f1_m: 0.8964 - val_loss: 0.5771 - val_accuracy: 0.8465 - val_f1_m: 0.7849
# Epoch 10/20
# 132/132 [==============================] - 13s 102ms/step - loss: 0.0380 - accuracy: 0.9917 - f1_m: 0.9160 - val_loss: 0.6165 - val_accuracy: 0.8358 - val_f1_m: 0.7691
# Epoch 11/20
# 132/132 [==============================] - 14s 103ms/step - loss: 0.0277 - accuracy: 0.9955 - f1_m: 0.9234 - val_loss: 0.6717 - val_accuracy: 0.8486 - val_f1_m: 0.7778
# Epoch 12/20
# 132/132 [==============================] - 14s 105ms/step - loss: 0.0250 - accuracy: 0.9948 - f1_m: 0.9351 - val_loss: 0.6998 - val_accuracy: 0.8401 - val_f1_m: 0.7814
# Epoch 13/20
# 132/132 [==============================] - 14s 106ms/step - loss: 0.0183 - accuracy: 0.9962 - f1_m: 0.9430 - val_loss: 0.7270 - val_accuracy: 0.8294 - val_f1_m: 0.7715
# Epoch 14/20
# 132/132 [==============================] - 13s 101ms/step - loss: 0.0162 - accuracy: 0.9976 - f1_m: 0.9430 - val_loss: 0.7852 - val_accuracy: 0.8337 - val_f1_m: 0.7640
# Epoch 15/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.0129 - accuracy: 0.9976 - f1_m: 0.9485 - val_loss: 0.7856 - val_accuracy: 0.8358 - val_f1_m: 0.7783
# Epoch 16/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9986 - f1_m: 0.9542Restoring model weights from the end of the best epoch: 11.
# 132/132 [==============================] - 12s 94ms/step - loss: 0.0100 - accuracy: 0.9986 - f1_m: 0.9542 - val_loss: 0.8724 - val_accuracy: 0.8273 - val_f1_m: 0.7965
# Epoch 00016: early stopping
# {'hidden': 'sigmoid', 'output': 'softmax'}
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 15, 16)            111920
#
#  bidirectional_9 (Bidirectio  (None, 15, 128)          41472
#  nal)
#
#  flatten_9 (Flatten)         (None, 1920)              0
#
#  dense_9 (Dense)             (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 15s 98ms/step - loss: 1.1022 - accuracy: 0.3847 - f1_m: 0.0887 - val_loss: 1.0711 - val_accuracy: 0.4755 - val_f1_m: 0.0000e+00
# Epoch 2/20
# 132/132 [==============================] - 13s 96ms/step - loss: 1.0142 - accuracy: 0.4948 - f1_m: 0.2916 - val_loss: 0.9116 - val_accuracy: 0.5629 - val_f1_m: 0.5257
# Epoch 3/20
# 132/132 [==============================] - 13s 99ms/step - loss: 0.8034 - accuracy: 0.6343 - f1_m: 0.5805 - val_loss: 0.7593 - val_accuracy: 0.6652 - val_f1_m: 0.6331
# Epoch 4/20
# 132/132 [==============================] - 14s 103ms/step - loss: 0.5295 - accuracy: 0.7934 - f1_m: 0.7822 - val_loss: 0.5822 - val_accuracy: 0.7740 - val_f1_m: 0.7642
# Epoch 5/20
# 132/132 [==============================] - 12s 95ms/step - loss: 0.3306 - accuracy: 0.8869 - f1_m: 0.8844 - val_loss: 0.6106 - val_accuracy: 0.7740 - val_f1_m: 0.7711
# Epoch 6/20
# 132/132 [==============================] - 12s 95ms/step - loss: 0.2219 - accuracy: 0.9310 - f1_m: 0.9298 - val_loss: 0.6037 - val_accuracy: 0.7846 - val_f1_m: 0.7856
# Epoch 7/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.1341 - accuracy: 0.9647 - f1_m: 0.9638 - val_loss: 0.7030 - val_accuracy: 0.7697 - val_f1_m: 0.7772
# Epoch 8/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.0915 - accuracy: 0.9772 - f1_m: 0.9760 - val_loss: 0.6371 - val_accuracy: 0.8209 - val_f1_m: 0.8206
# Epoch 9/20
# 132/132 [==============================] - 12s 95ms/step - loss: 0.0558 - accuracy: 0.9879 - f1_m: 0.9878 - val_loss: 0.6442 - val_accuracy: 0.8252 - val_f1_m: 0.8249
# Epoch 10/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0455 - accuracy: 0.9893 - f1_m: 0.9896 - val_loss: 0.7121 - val_accuracy: 0.8124 - val_f1_m: 0.8131
# Epoch 11/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.0420 - accuracy: 0.9896 - f1_m: 0.9894 - val_loss: 0.8787 - val_accuracy: 0.7591 - val_f1_m: 0.7574
# Epoch 12/20
# 132/132 [==============================] - 13s 95ms/step - loss: 0.0291 - accuracy: 0.9931 - f1_m: 0.9935 - val_loss: 0.7912 - val_accuracy: 0.8060 - val_f1_m: 0.8126
# Epoch 13/20
# 132/132 [==============================] - 13s 97ms/step - loss: 0.0234 - accuracy: 0.9957 - f1_m: 0.9956 - val_loss: 0.8742 - val_accuracy: 0.8081 - val_f1_m: 0.8091
# Epoch 14/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9967 - f1_m: 0.9968Restoring model weights from the end of the best epoch: 9.
# 132/132 [==============================] - 15s 110ms/step - loss: 0.0183 - accuracy: 0.9967 - f1_m: 0.9968 - val_loss: 0.8182 - val_accuracy: 0.8038 - val_f1_m: 0.8059
# Epoch 00014: early stopping
# {'hidden': 'tanh', 'output': 'sigmoid'}
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_11 (Embedding)    (None, 15, 16)            111920
#
#  bidirectional_10 (Bidirecti  (None, 15, 128)          41472
#  onal)
#
#  flatten_10 (Flatten)        (None, 1920)              0
#
#  dense_10 (Dense)            (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 9s 22ms/step - loss: 0.8927 - accuracy: 0.5595 - f1_m: 0.5930 - val_loss: 0.6178 - val_accuracy: 0.7527 - val_f1_m: 0.7277
# Epoch 2/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.3623 - accuracy: 0.8722 - f1_m: 0.8389 - val_loss: 0.4719 - val_accuracy: 0.8230 - val_f1_m: 0.7950
# Epoch 3/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.1255 - accuracy: 0.9639 - f1_m: 0.9307 - val_loss: 0.5786 - val_accuracy: 0.8188 - val_f1_m: 0.8124
# Epoch 4/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0657 - accuracy: 0.9801 - f1_m: 0.9545 - val_loss: 0.5559 - val_accuracy: 0.8166 - val_f1_m: 0.8005
# Epoch 5/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0377 - accuracy: 0.9903 - f1_m: 0.9640 - val_loss: 0.7126 - val_accuracy: 0.8188 - val_f1_m: 0.7981
# Epoch 6/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0406 - accuracy: 0.9879 - f1_m: 0.9642 - val_loss: 0.6404 - val_accuracy: 0.8337 - val_f1_m: 0.8227
# Epoch 7/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0312 - accuracy: 0.9926 - f1_m: 0.9700 - val_loss: 0.5701 - val_accuracy: 0.8145 - val_f1_m: 0.8021
# Epoch 8/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0199 - accuracy: 0.9953 - f1_m: 0.9742 - val_loss: 0.7621 - val_accuracy: 0.8188 - val_f1_m: 0.8150
# Epoch 9/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0123 - accuracy: 0.9979 - f1_m: 0.9797 - val_loss: 0.9549 - val_accuracy: 0.8380 - val_f1_m: 0.8233
# Epoch 10/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0062 - accuracy: 0.9988 - f1_m: 0.9872 - val_loss: 0.8125 - val_accuracy: 0.8081 - val_f1_m: 0.7837
# Epoch 11/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0115 - accuracy: 0.9976 - f1_m: 0.9783 - val_loss: 0.8125 - val_accuracy: 0.8017 - val_f1_m: 0.8023
# Epoch 12/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0148 - accuracy: 0.9943 - f1_m: 0.9674 - val_loss: 0.8214 - val_accuracy: 0.8380 - val_f1_m: 0.7801
# Epoch 13/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0252 - accuracy: 0.9943 - f1_m: 0.9555 - val_loss: 0.8438 - val_accuracy: 0.8380 - val_f1_m: 0.8060
# Epoch 14/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9976 - f1_m: 0.9813Restoring model weights from the end of the best epoch: 9.
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0096 - accuracy: 0.9976 - f1_m: 0.9813 - val_loss: 0.8025 - val_accuracy: 0.8358 - val_f1_m: 0.8215
# Epoch 00014: early stopping
# {'hidden': 'tanh', 'output': 'softmax'}
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_12 (Embedding)    (None, 15, 16)            111920
#
#  bidirectional_11 (Bidirecti  (None, 15, 128)          41472
#  onal)
#
#  flatten_11 (Flatten)        (None, 1920)              0
#
#  dense_11 (Dense)            (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 5s 22ms/step - loss: 0.8784 - accuracy: 0.5783 - f1_m: 0.4072 - val_loss: 0.6411 - val_accuracy: 0.7292 - val_f1_m: 0.7158
# Epoch 2/20
# 132/132 [==============================] - 3s 21ms/step - loss: 0.3893 - accuracy: 0.8612 - f1_m: 0.8576 - val_loss: 0.4857 - val_accuracy: 0.8188 - val_f1_m: 0.8181
# Epoch 3/20
# 132/132 [==============================] - 2s 17ms/step - loss: 0.1407 - accuracy: 0.9599 - f1_m: 0.9595 - val_loss: 0.5129 - val_accuracy: 0.8145 - val_f1_m: 0.8107
# Epoch 4/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0711 - accuracy: 0.9810 - f1_m: 0.9809 - val_loss: 0.5491 - val_accuracy: 0.8209 - val_f1_m: 0.8252
# Epoch 5/20
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0386 - accuracy: 0.9903 - f1_m: 0.9902 - val_loss: 0.7289 - val_accuracy: 0.8209 - val_f1_m: 0.8246
# Epoch 6/20
# 132/132 [==============================] - 2s 15ms/step - loss: 0.0323 - accuracy: 0.9926 - f1_m: 0.9927 - val_loss: 0.8808 - val_accuracy: 0.8166 - val_f1_m: 0.8177
# Epoch 7/20
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0225 - accuracy: 0.9941 - f1_m: 0.9940 - val_loss: 0.7962 - val_accuracy: 0.8038 - val_f1_m: 0.8010
# Epoch 8/20
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0173 - accuracy: 0.9950 - f1_m: 0.9950 - val_loss: 0.8121 - val_accuracy: 0.8145 - val_f1_m: 0.8125
# Epoch 9/20
# 131/132 [============================>.] - ETA: 0s - loss: 0.0128 - accuracy: 0.9974 - f1_m: 0.9973Restoring model weights from the end of the best epoch: 4.
# 132/132 [==============================] - 2s 14ms/step - loss: 0.0127 - accuracy: 0.9974 - f1_m: 0.9973 - val_loss: 0.8034 - val_accuracy: 0.8102 - val_f1_m: 0.8121
# Epoch 00009: early stopping

# %%
def compareAccuracy(result,activation):
    plt.plot(result[0].history['accuracy'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['accuracy'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['accuracy'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['accuracy'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['accuracy'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['accuracy'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title("Akurasi Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareAccuracy(result,activation)
def compareValidationAccuracy(result,activation):
    plt.plot(result[0].history['val_accuracy'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['val_accuracy'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['val_accuracy'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['val_accuracy'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['val_accuracy'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['val_accuracy'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title("Validasi Akurasi Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareValidationAccuracy(result,activation)

# %%
def compareLoss(result,activation):
    plt.plot(result[0].history['loss'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['loss'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['loss'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['loss'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['loss'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['loss'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title("Loss Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareLoss(result,activation)
def compareValidationLoss(result,activation):
    plt.plot(result[0].history['val_loss'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['val_loss'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['val_loss'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['val_loss'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['val_loss'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['val_loss'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title("Validasi Loss Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareValidationLoss(result,activation)

# %%
def compareF1Score(result,activation):
    plt.plot(result[0].history['f1_m'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['f1_m'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['f1_m'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['f1_m'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['f1_m'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['f1_m'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title(" F1 Score Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareF1Score(result,activation)
def compareValidationF1Score(result,activation):
    plt.plot(result[0].history['val_f1_m'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['val_f1_m'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['val_f1_m'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['val_f1_m'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['val_f1_m'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['val_f1_m'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Epochs")
    plt.ylabel("Nilai")
    plt.title(" Validasi F1 Score Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareValidationF1Score(result,activation)

# %%
for i in range(6):
    temp=models[i].evaluate(x_test,y_test)
    print("Model dengan hidden layer {} dan output layer {} dengan matrix evaluasi".format(activation[i]['hidden'],activation[i]['output']),temp)
# Out:
# 17/17 [==============================] - 0s 22ms/step - loss: 0.6094 - accuracy: 0.8772 - f1_m: 0.8680
# Model dengan hidden layer relu dan output layer sigmoid dengan matrix evaluasi [0.6094195246696472, 0.8771592974662781, 0.8680157661437988]
# 17/17 [==============================] - 0s 21ms/step - loss: 0.5539 - accuracy: 0.8637 - f1_m: 0.8696
# Model dengan hidden layer relu dan output layer softmax dengan matrix evaluasi [0.5538613200187683, 0.863723635673523, 0.8695597052574158]
# 17/17 [==============================] - 0s 16ms/step - loss: 0.6183 - accuracy: 0.8273 - f1_m: 0.7859
# Model dengan hidden layer sigmoid dan output layer sigmoid dengan matrix evaluasi [0.6183249950408936, 0.8272552490234375, 0.7859273552894592]
# 17/17 [==============================] - 0s 13ms/step - loss: 0.6177 - accuracy: 0.8311 - f1_m: 0.8398
# Model dengan hidden layer sigmoid dan output layer softmax dengan matrix evaluasi [0.6176862120628357, 0.8310940265655518, 0.8398400545120239]
# 17/17 [==============================] - 0s 9ms/step - loss: 0.9926 - accuracy: 0.8330 - f1_m: 0.8071
# Model dengan hidden layer tanh dan output layer sigmoid dengan matrix evaluasi [0.9925572276115417, 0.8330134153366089, 0.8071441054344177]
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5430 - accuracy: 0.8234 - f1_m: 0.8255
# Model dengan hidden layer tanh dan output layer softmax dengan matrix evaluasi [0.543012797832489, 0.823416531085968, 0.825456976890564]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
for item in models:
    predict=item.predict(x_test)
    confusion=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(predict,axis=1))
    display=ConfusionMatrixDisplay(confusion_matrix=confusion)
    display.plot()

# %%
model=createSimpleModel(1)
history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Skripsi\Selena Gomez\activation.ipynb Cell 28 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> model=createSimpleModel(1)
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
#
# d:\Skripsi\Selena Gomez\activation.ipynb Cell 28 in createSimpleModel(activation)
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> def createSimpleModel(activation):
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a>     model=tf.keras.models.Sequential([
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a>             tf.keras.layers.Embedding(len(tokenizer.word_index),16,input_length=max_len),
# ----> <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=3'>4</a>             tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences=True,activation=activation['hidden'])),
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=4'>5</a>             tf.keras.layers.Flatten(),
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=5'>6</a>             tf.keras.layers.Dense(3, activation=activation['output'])
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=6'>7</a>         ])
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=7'>8</a>     model.compile(loss='categorical_crossentropy',optimizer=tf.keras.optimizers.Adam(),metrics=['accuracy',f1_m])
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/activation.ipynb#X40sZmlsZQ%3D%3D?line=8'>9</a>     model.summary()
#
# TypeError: 'int' object is not subscriptable

# %%
temp=model.evaluate(x_test,y_test)
temp
# Out:
# 17/17 [==============================] - 0s 11ms/step - loss: 0.1171 - accuracy: 0.8100 - f1_m: 0.8079
# [0.11711768805980682, 0.8099808096885681, 0.8078767657279968]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
predict=model.predict(x_test)
confusion=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(predict,axis=1))
display=ConfusionMatrixDisplay(confusion_matrix=confusion)
display.plot()

# %%
import matplotlib.pyplot as plt

def plot_graphs(history):
  figure, axis = plt.subplots(2, 2)
  figure.set_size_inches(18.5, 10.5, forward=True)

  axis[0,0].plot(history.history['accuracy'])
  axis[0,0].plot(history.history['val_accuracy'])
  axis[0,0].set_title('Accuracy')
  axis[0,0].legend(['accuracy','val_accuracy'])

  axis[0,1].plot(history.history['loss'])
  axis[0,1].plot(history.history['val_loss'])
  axis[0,1].set_title('Loss')
  axis[0,1].legend(['loss','val_loss'])

  axis[1,0].plot(history.history['f1_m'])
  axis[1,0].plot(history.history['val_f1_m'])
  axis[1,0].set_title('F1-Score')
  axis[1,0].legend(['f1_m','val_f1_m'])
  plt.show()

# %%
plot_graphs(history=history)

# %%
def createComplexModel(skenario):
    if skenario ==1:
        model=tf.keras.models.Sequential([
            tf.keras.layers.Embedding(len(tokenizer.word_index),128,input_length=max_len),
            tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2),
            tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2),
            tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(512,activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(3, activation='softmax')
        ])
        model.compile(loss='mse',optimizer=tf.keras.optimizers.RMSprop(),metrics=['accuracy',f1_m])
    else:
        model=tf.keras.models.Sequential([
        tf.keras.layers.Embedding(len(tokenizer.word_index),128,input_length=max_len),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512,activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(3,activation='softmax')
        ])
        model.compile(loss='mse',optimizer=tf.keras.optimizers.RMSprop(),metrics=['accuracy',f1_m])
    model.summary()
    return model

# %%
model=createComplexModel(2)
history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 15, 128)           895360
#
#  bidirectional_12 (Bidirecti  (None, 15, 256)          263168
#  onal)
#
#  bidirectional_13 (Bidirecti  (None, 15, 256)          394240
#  onal)
#
#  bidirectional_14 (Bidirecti  (None, 15, 256)          394240
#  onal)
#
#  flatten_10 (Flatten)        (None, 3840)              0
#
#  dense_18 (Dense)            (None, 512)               1966592
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_19 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 3,915,139
# Trainable params: 3,915,139
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 18s 55ms/step - loss: 0.8239 - accuracy: 0.6321 - f1_m: 0.5431 - val_loss: 0.5873 - val_accuracy: 0.7932 - val_f1_m: 0.7701
# Epoch 2/20
# 132/132 [==============================] - 5s 38ms/step - loss: 0.3966 - accuracy: 0.8653 - f1_m: 0.8647 - val_loss: 0.5742 - val_accuracy: 0.7996 - val_f1_m: 0.8013
# Epoch 3/20
# 132/132 [==============================] - 5s 37ms/step - loss: 0.2500 - accuracy: 0.9227 - f1_m: 0.9212 - val_loss: 0.3869 - val_accuracy: 0.8678 - val_f1_m: 0.8560
# Epoch 4/20
# 132/132 [==============================] - 5s 40ms/step - loss: 0.1565 - accuracy: 0.9542 - f1_m: 0.9539 - val_loss: 0.4261 - val_accuracy: 0.8401 - val_f1_m: 0.8421
# Epoch 5/20
# 132/132 [==============================] - 5s 38ms/step - loss: 0.1231 - accuracy: 0.9635 - f1_m: 0.9626 - val_loss: 0.4509 - val_accuracy: 0.8571 - val_f1_m: 0.8539
# Epoch 6/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.1005 - accuracy: 0.9720 - f1_m: 0.9722 - val_loss: 0.3989 - val_accuracy: 0.8699 - val_f1_m: 0.8620
# Epoch 7/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0775 - accuracy: 0.9763 - f1_m: 0.9766 - val_loss: 0.5164 - val_accuracy: 0.8785 - val_f1_m: 0.8808
# Epoch 8/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0611 - accuracy: 0.9817 - f1_m: 0.9817 - val_loss: 0.4865 - val_accuracy: 0.8785 - val_f1_m: 0.8807
# Epoch 9/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0544 - accuracy: 0.9848 - f1_m: 0.9846 - val_loss: 0.6683 - val_accuracy: 0.8507 - val_f1_m: 0.8520
# Epoch 10/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0439 - accuracy: 0.9879 - f1_m: 0.9878 - val_loss: 1.9408 - val_accuracy: 0.8721 - val_f1_m: 0.8714
# Epoch 11/20
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0470 - accuracy: 0.9886 - f1_m: 0.9887 - val_loss: 0.9230 - val_accuracy: 0.8763 - val_f1_m: 0.8794
# Epoch 12/20
# 131/132 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9921 - f1_m: 0.9921- ETA: 0s - loss: 0.0313 - accuracy: 0.9927 - Restoring model weights from the end of the best epoch: 7.
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0317 - accuracy: 0.9922 - f1_m: 0.9922 - val_loss: 1.1515 - val_accuracy: 0.8614 - val_f1_m: 0.8668
# Epoch 00012: early stopping

# %%
temp=model.evaluate(x_test,y_test)
temp
# Out:
# 17/17 [==============================] - 1s 32ms/step - loss: 0.5319 - accuracy: 0.8580 - f1_m: 0.8578
# [0.5319363474845886, 0.8579654693603516, 0.8578073382377625]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
predict=model.predict(x_test)
confusion=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(predict,axis=1))
display=ConfusionMatrixDisplay(confusion_matrix=confusion)
display.plot()

# %%
plot_graphs(history=history)
