# %% [markdown]
# Melakukan import libraries yang dibutukan

# %%
import pandas as pd
import tensorflow as tf

# %%
data=pd.read_excel('./selenagomez_clean.xlsx')
del data['Unnamed: 0']
data
# Out:
#                           created_at         username  \
# 0     Thu Mar 02 23:59:30 +0000 2023        darkonsun
# 1     Thu Mar 02 23:56:18 +0000 2023    babyyyannieee
# 2     Thu Mar 02 23:55:57 +0000 2023     likabeast101
# 3     Thu Mar 02 23:55:36 +0000 2023   whoismelanyway
# 4     Thu Mar 02 23:54:50 +0000 2023         _mayyraa
# ...                              ...              ...
# 5201  Wed Mar 01 10:19:04 +0000 2023  SAFFAOnAirRadio
# 5202  Wed Mar 01 10:19:01 +0000 2023        tshepiixx
# 5203  Wed Mar 01 10:17:59 +0000 2023     Chief_I_H8_U
# 5204  Wed Mar 01 10:15:42 +0000 2023     vinalraswati
# 5205  Wed Mar 01 10:13:24 +0000 2023       TheSwaddle
#
#                                                    text  \
# 0     social media is a disease and this hailey bieb...
# 1     Justin Bieber &amp; Selena Gomez followed each...
# 2                      Selena Gomez drove by my house 🙀
# 3     I understand hailey Bieber because if my husba...
# 4     but then i always realize because SELENA GOMEZ...
# ...                                                 ...
# 5201  @SAFFAOnAirRadio is now playing, Selena Gomez,...
# 5202                     Go follow Selena Gomez on IG 😡
# 5203  @Ricius496 @endlessbonerz Selena Gomez has a m...
# 5204  I still can taste it and i hate it. \n\nPeople...
# 5205  Over the past few days, the alleged feud betwe...
#
#                                            preprocessed sentiment
# 0     social media diseas hailey bieber selena gomez...   Neutral
# 1     justin bieber amp selena gomez follow twitter ...   Neutral
# 2                               selena gomez drive hous   Neutral
# 3     understand hailey bieber husband ex selena gom...   Neutral
# 4             alway realiz selena gomez alway look good  Positive
# ...                                                 ...       ...
# 5201  saffaonairradio play selena gomez marshmello w...  Positive
# 5202                          go follow selena gomez ig   Neutral
# 5203  riciu endlessbonerz selena gomez medic issu st...   Neutral
# 5204            still tast hate peopl know selena gomez  Negative
# 5205  past day alleg feud selena gomez hailey bieber...  Negative
#
# [5206 rows x 5 columns]

# %%
data=data[['preprocessed','sentiment']]
data
# Out:
#                                            preprocessed sentiment
# 0     social media diseas hailey bieber selena gomez...   Neutral
# 1     justin bieber amp selena gomez follow twitter ...   Neutral
# 2                               selena gomez drive hous   Neutral
# 3     understand hailey bieber husband ex selena gom...   Neutral
# 4             alway realiz selena gomez alway look good  Positive
# ...                                                 ...       ...
# 5201  saffaonairradio play selena gomez marshmello w...  Positive
# 5202                          go follow selena gomez ig   Neutral
# 5203  riciu endlessbonerz selena gomez medic issu st...   Neutral
# 5204            still tast hate peopl know selena gomez  Negative
# 5205  past day alleg feud selena gomez hailey bieber...  Negative
#
# [5206 rows x 2 columns]

# %%
data.sentiment = pd.Categorical(pd.factorize(data.sentiment)[0])
data
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4364\1650668707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.sentiment = pd.Categorical(pd.factorize(data.sentiment)[0])
#                                            preprocessed sentiment
# 0     social media diseas hailey bieber selena gomez...         0
# 1     justin bieber amp selena gomez follow twitter ...         0
# 2                               selena gomez drive hous         0
# 3     understand hailey bieber husband ex selena gom...         0
# 4             alway realiz selena gomez alway look good         1
# ...                                                 ...       ...
# 5201  saffaonairradio play selena gomez marshmello w...         1
# 5202                          go follow selena gomez ig         0
# 5203  riciu endlessbonerz selena gomez medic issu st...         0
# 5204            still tast hate peopl know selena gomez         2
# 5205  past day alleg feud selena gomez hailey bieber...         2
#
# [5206 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
#vectorizer = TfidfVectorizer()
##vectors = vectorizer.fit_transform(data['preprocessed'])
#feature_names = vectorizer.get_feature_names()
#dense = vectors.todense()
#denselist=dense.tolist()

# %%
max_len=15
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
tokenizer=Tokenizer(oov_token=oov_tok)
tokenizer.fit_on_texts(data['preprocessed'])

# %%
len(tokenizer.word_index)
# Out:
# 6995

# %%
sequences=tokenizer.texts_to_sequences(data['preprocessed'])
padded=pad_sequences(sequences=sequences,padding=padding_type,truncating=trunc_type,maxlen=max_len)
temp=0
kamus={}
for item in sequences:
    coba=len(item)
    if coba not in kamus:
        kamus[coba]=1
    else:
        kamus[coba]+=1

# %%
import matplotlib.pylab as plt

lists = sorted(kamus.items()) # sorted by key, return a list of tuples

x, y = zip(*lists) # unpack a list of pairs into two tuples

plt.plot(x, y)
plt.show()

# %%
sequences=tokenizer.texts_to_sequences(data['preprocessed'])
padded=pad_sequences(sequences=sequences,padding=padding_type,truncating=trunc_type,maxlen=max_len)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(padded,data['sentiment'],test_size=0.1)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4685, 15), (521, 15), (4685,), (521,))

# %%
y_train= tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test= tf.keras.utils.to_categorical(y_test, num_classes=3)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((4685, 15), (521, 15), (4685, 3), (521, 3))

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def createSimpleModel(activation):
    model=tf.keras.models.Sequential([
            tf.keras.layers.Embedding(len(tokenizer.word_index),16,input_length=max_len),
            tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,return_sequences=True,activation=activation['hidden'])),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(3, activation=activation['output'])
        ])
    model.compile(loss='categorical_crossentropy',optimizer=tf.keras.optimizers.Adam(),metrics=['accuracy',f1_m])
    model.summary()
    return model

# %%
callback = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    min_delta=0,
    patience=5,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

# %%
#from scikeras.wrappers import KerasClassifier
#from sklearn.model_selection import KFold
#from sklearn.model_selection import cross_val_score
##estimator = KerasClassifier(build_fn=createSimpleModel(2), epochs=20, verbose=1,callbacks=[callback],validation_split=0.1)
#kfold = KFold(n_splits=5, shuffle=True)
#results = cross_val_score(estimator, x_train, y_train, cv=kfold,scoring='accuracy')
#results

# %%
activation=[{'hidden':'relu','output':'sigmoid'},{'hidden':'relu','output':'softmax',},{'hidden':'sigmoid','output':'sigmoid'},{'hidden':'sigmoid','output':'softmax'},
            {'hidden':'tanh','output':'sigmoid'},{'hidden':'tanh','output':'softmax'}]
result=[]
models=[]
for item in activation:
    print(item)
    model=createSimpleModel(activation=item)
    history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
    models.append(model)
    result.append(history)
# Out:
# {'hidden': 'relu', 'output': 'sigmoid'}
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 15, 16)            111920
#
#  bidirectional (Bidirectiona  (None, 15, 128)          41472
#  l)
#
#  flatten (Flatten)           (None, 1920)              0
#
#  dense (Dense)               (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 18s 95ms/step - loss: 0.9364 - accuracy: 0.5396 - f1_m: 0.5547 - val_loss: 0.6765 - val_accuracy: 0.7292 - val_f1_m: 0.6919
# Epoch 2/20
# 132/132 [==============================] - 12s 92ms/step - loss: 0.4243 - accuracy: 0.8534 - f1_m: 0.8132 - val_loss: 0.4981 - val_accuracy: 0.8380 - val_f1_m: 0.8216
# Epoch 3/20
# 132/132 [==============================] - 12s 91ms/step - loss: 0.1694 - accuracy: 0.9526 - f1_m: 0.9389 - val_loss: 0.4045 - val_accuracy: 0.8785 - val_f1_m: 0.8550
# Epoch 4/20
# 132/132 [==============================] - 12s 91ms/step - loss: 0.0768 - accuracy: 0.9794 - f1_m: 0.9730 - val_loss: 0.4885 - val_accuracy: 0.8422 - val_f1_m: 0.8454
# Epoch 5/20
# 132/132 [==============================] - 12s 92ms/step - loss: 0.0403 - accuracy: 0.9900 - f1_m: 0.9860 - val_loss: 0.5063 - val_accuracy: 0.8486 - val_f1_m: 0.8474
# Epoch 6/20
# 132/132 [==============================] - 12s 92ms/step - loss: 0.0253 - accuracy: 0.9936 - f1_m: 0.9906 - val_loss: 0.8978 - val_accuracy: 0.8422 - val_f1_m: 0.8450
# Epoch 7/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.0220 - accuracy: 0.9948 - f1_m: 0.9917 - val_loss: 0.6132 - val_accuracy: 0.8507 - val_f1_m: 0.8469
# Epoch 8/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9924 - f1_m: 0.9872Restoring model weights from the end of the best epoch: 3.
# 132/132 [==============================] - 13s 98ms/step - loss: 0.0310 - accuracy: 0.9924 - f1_m: 0.9872 - val_loss: 1.0357 - val_accuracy: 0.8358 - val_f1_m: 0.8359
# Epoch 00008: early stopping
# {'hidden': 'relu', 'output': 'softmax'}
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 15, 16)            111920
#
#  bidirectional_1 (Bidirectio  (None, 15, 128)          41472
#  nal)
#
#  flatten_1 (Flatten)         (None, 1920)              0
#
#  dense_1 (Dense)             (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 16s 105ms/step - loss: 0.9437 - accuracy: 0.5197 - f1_m: 0.3426 - val_loss: 0.6970 - val_accuracy: 0.6844 - val_f1_m: 0.6461
# Epoch 2/20
# 132/132 [==============================] - 15s 112ms/step - loss: 0.4752 - accuracy: 0.8069 - f1_m: 0.7907 - val_loss: 0.4457 - val_accuracy: 0.8422 - val_f1_m: 0.8410
# Epoch 3/20
# 132/132 [==============================] - 13s 99ms/step - loss: 0.2086 - accuracy: 0.9364 - f1_m: 0.9363 - val_loss: 0.3910 - val_accuracy: 0.8763 - val_f1_m: 0.8795
# Epoch 4/20
# 132/132 [==============================] - 13s 98ms/step - loss: 0.0996 - accuracy: 0.9711 - f1_m: 0.9711 - val_loss: 0.4747 - val_accuracy: 0.8465 - val_f1_m: 0.8488
# Epoch 5/20
# 132/132 [==============================] - 13s 97ms/step - loss: 0.0535 - accuracy: 0.9860 - f1_m: 0.9858 - val_loss: 0.7527 - val_accuracy: 0.8529 - val_f1_m: 0.8504
# Epoch 6/20
# 132/132 [==============================] - 13s 97ms/step - loss: 0.0373 - accuracy: 0.9912 - f1_m: 0.9913 - val_loss: 0.6488 - val_accuracy: 0.8785 - val_f1_m: 0.8815
# Epoch 7/20
# 132/132 [==============================] - 12s 95ms/step - loss: 0.0247 - accuracy: 0.9938 - f1_m: 0.9939 - val_loss: 0.9151 - val_accuracy: 0.8785 - val_f1_m: 0.8785
# Epoch 8/20
# 132/132 [==============================] - 12s 93ms/step - loss: 0.0417 - accuracy: 0.9903 - f1_m: 0.9898 - val_loss: 0.6231 - val_accuracy: 0.8529 - val_f1_m: 0.8522
# Epoch 9/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.0123 - accuracy: 0.9969 - f1_m: 0.9970 - val_loss: 1.1244 - val_accuracy: 0.8550 - val_f1_m: 0.8593
# Epoch 10/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.0091 - accuracy: 0.9983 - f1_m: 0.9981 - val_loss: 1.2646 - val_accuracy: 0.8358 - val_f1_m: 0.8372
# Epoch 11/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9926 - f1_m: 0.9923Restoring model weights from the end of the best epoch: 6.
# 132/132 [==============================] - 13s 96ms/step - loss: 0.0268 - accuracy: 0.9926 - f1_m: 0.9923 - val_loss: 0.5337 - val_accuracy: 0.8614 - val_f1_m: 0.8657
# Epoch 00011: early stopping
# {'hidden': 'sigmoid', 'output': 'sigmoid'}
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 15, 16)            111920
#
#  bidirectional_2 (Bidirectio  (None, 15, 128)          41472
#  nal)
#
#  flatten_2 (Flatten)         (None, 1920)              0
#
#  dense_2 (Dense)             (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 16s 106ms/step - loss: 1.0925 - accuracy: 0.3947 - f1_m: 0.5006 - val_loss: 1.0561 - val_accuracy: 0.4115 - val_f1_m: 0.5318
# Epoch 2/20
# 132/132 [==============================] - 13s 97ms/step - loss: 0.9917 - accuracy: 0.5116 - f1_m: 0.5379 - val_loss: 0.9067 - val_accuracy: 0.6055 - val_f1_m: 0.5584
# Epoch 3/20
# 132/132 [==============================] - 13s 100ms/step - loss: 0.7494 - accuracy: 0.6850 - f1_m: 0.6265 - val_loss: 0.7518 - val_accuracy: 0.6525 - val_f1_m: 0.6239
# Epoch 4/20
# 132/132 [==============================] - 13s 97ms/step - loss: 0.4522 - accuracy: 0.8385 - f1_m: 0.7110 - val_loss: 0.5430 - val_accuracy: 0.7697 - val_f1_m: 0.6931
# Epoch 5/20
# 132/132 [==============================] - 13s 97ms/step - loss: 0.2637 - accuracy: 0.9111 - f1_m: 0.7591 - val_loss: 0.5006 - val_accuracy: 0.8294 - val_f1_m: 0.7508
# Epoch 6/20
# 132/132 [==============================] - 13s 97ms/step - loss: 0.1586 - accuracy: 0.9523 - f1_m: 0.8014 - val_loss: 0.4852 - val_accuracy: 0.8422 - val_f1_m: 0.7500
# Epoch 7/20
# 132/132 [==============================] - 13s 99ms/step - loss: 0.0949 - accuracy: 0.9732 - f1_m: 0.8425 - val_loss: 0.5177 - val_accuracy: 0.8422 - val_f1_m: 0.7520
# Epoch 8/20
# 132/132 [==============================] - 14s 103ms/step - loss: 0.0664 - accuracy: 0.9846 - f1_m: 0.8645 - val_loss: 0.5653 - val_accuracy: 0.8273 - val_f1_m: 0.7730
# Epoch 9/20
# 132/132 [==============================] - 13s 99ms/step - loss: 0.0470 - accuracy: 0.9898 - f1_m: 0.8929 - val_loss: 0.6113 - val_accuracy: 0.8337 - val_f1_m: 0.7701
# Epoch 10/20
# 132/132 [==============================] - 13s 97ms/step - loss: 0.0445 - accuracy: 0.9891 - f1_m: 0.8915 - val_loss: 0.6993 - val_accuracy: 0.8273 - val_f1_m: 0.7613
# Epoch 11/20
# 132/132 [==============================] - 13s 97ms/step - loss: 0.0284 - accuracy: 0.9955 - f1_m: 0.9084 - val_loss: 0.7027 - val_accuracy: 0.8443 - val_f1_m: 0.7782
# Epoch 12/20
# 132/132 [==============================] - 13s 100ms/step - loss: 0.0221 - accuracy: 0.9967 - f1_m: 0.9241 - val_loss: 0.7389 - val_accuracy: 0.8337 - val_f1_m: 0.7868
# Epoch 13/20
# 132/132 [==============================] - 13s 99ms/step - loss: 0.0189 - accuracy: 0.9976 - f1_m: 0.9267 - val_loss: 0.7744 - val_accuracy: 0.8209 - val_f1_m: 0.7757
# Epoch 14/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.0209 - accuracy: 0.9950 - f1_m: 0.9267 - val_loss: 0.7797 - val_accuracy: 0.8422 - val_f1_m: 0.7940
# Epoch 15/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.0170 - accuracy: 0.9976 - f1_m: 0.9347 - val_loss: 0.8264 - val_accuracy: 0.8273 - val_f1_m: 0.7747
# Epoch 16/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9976 - f1_m: 0.9382Restoring model weights from the end of the best epoch: 11.
# 132/132 [==============================] - 13s 96ms/step - loss: 0.0120 - accuracy: 0.9976 - f1_m: 0.9382 - val_loss: 0.8395 - val_accuracy: 0.8252 - val_f1_m: 0.7836
# Epoch 00016: early stopping
# {'hidden': 'sigmoid', 'output': 'softmax'}
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 15, 16)            111920
#
#  bidirectional_3 (Bidirectio  (None, 15, 128)          41472
#  nal)
#
#  flatten_3 (Flatten)         (None, 1920)              0
#
#  dense_3 (Dense)             (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 15s 98ms/step - loss: 1.0834 - accuracy: 0.3921 - f1_m: 0.0784 - val_loss: 1.0327 - val_accuracy: 0.4648 - val_f1_m: 0.0399
# Epoch 2/20
# 132/132 [==============================] - 13s 96ms/step - loss: 1.0173 - accuracy: 0.4777 - f1_m: 0.2563 - val_loss: 0.9222 - val_accuracy: 0.5778 - val_f1_m: 0.5218
# Epoch 3/20
# 132/132 [==============================] - 13s 98ms/step - loss: 0.8119 - accuracy: 0.6418 - f1_m: 0.5665 - val_loss: 0.7515 - val_accuracy: 0.6652 - val_f1_m: 0.6373
# Epoch 4/20
# 132/132 [==============================] - 13s 102ms/step - loss: 0.5157 - accuracy: 0.8100 - f1_m: 0.8000 - val_loss: 0.5711 - val_accuracy: 0.7697 - val_f1_m: 0.7609
# Epoch 5/20
# 132/132 [==============================] - 13s 100ms/step - loss: 0.2949 - accuracy: 0.9016 - f1_m: 0.9026 - val_loss: 0.5591 - val_accuracy: 0.7697 - val_f1_m: 0.7694
# Epoch 6/20
# 132/132 [==============================] - 13s 99ms/step - loss: 0.1689 - accuracy: 0.9514 - f1_m: 0.9506 - val_loss: 0.4612 - val_accuracy: 0.8486 - val_f1_m: 0.8473
# Epoch 7/20
# 132/132 [==============================] - 13s 101ms/step - loss: 0.1067 - accuracy: 0.9708 - f1_m: 0.9707 - val_loss: 0.4735 - val_accuracy: 0.8657 - val_f1_m: 0.8667
# Epoch 8/20
# 132/132 [==============================] - 13s 102ms/step - loss: 0.0739 - accuracy: 0.9817 - f1_m: 0.9823 - val_loss: 0.5514 - val_accuracy: 0.8337 - val_f1_m: 0.8334
# Epoch 9/20
# 132/132 [==============================] - 13s 101ms/step - loss: 0.0615 - accuracy: 0.9853 - f1_m: 0.9851 - val_loss: 0.4914 - val_accuracy: 0.8571 - val_f1_m: 0.8632
# Epoch 10/20
# 132/132 [==============================] - 14s 102ms/step - loss: 0.0388 - accuracy: 0.9924 - f1_m: 0.9924 - val_loss: 0.5265 - val_accuracy: 0.8443 - val_f1_m: 0.8478
# Epoch 11/20
# 132/132 [==============================] - 15s 113ms/step - loss: 0.0338 - accuracy: 0.9945 - f1_m: 0.9942 - val_loss: 0.5694 - val_accuracy: 0.8401 - val_f1_m: 0.8427
# Epoch 12/20
# 132/132 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9955 - f1_m: 0.9951Restoring model weights from the end of the best epoch: 7.
# 132/132 [==============================] - 16s 118ms/step - loss: 0.0269 - accuracy: 0.9955 - f1_m: 0.9951 - val_loss: 0.6503 - val_accuracy: 0.8145 - val_f1_m: 0.8144
# Epoch 00012: early stopping
# {'hidden': 'tanh', 'output': 'sigmoid'}
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 15, 16)            111920
#
#  bidirectional_4 (Bidirectio  (None, 15, 128)          41472
#  nal)
#
#  flatten_4 (Flatten)         (None, 1920)              0
#
#  dense_4 (Dense)             (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 9s 24ms/step - loss: 0.8968 - accuracy: 0.5586 - f1_m: 0.5800 - val_loss: 0.6784 - val_accuracy: 0.7207 - val_f1_m: 0.6611
# Epoch 2/20
# 132/132 [==============================] - 2s 17ms/step - loss: 0.3692 - accuracy: 0.8731 - f1_m: 0.8248 - val_loss: 0.4293 - val_accuracy: 0.8507 - val_f1_m: 0.8206
# Epoch 3/20
# 132/132 [==============================] - 2s 17ms/step - loss: 0.1277 - accuracy: 0.9628 - f1_m: 0.9338 - val_loss: 0.4253 - val_accuracy: 0.8721 - val_f1_m: 0.8427
# Epoch 4/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0616 - accuracy: 0.9834 - f1_m: 0.9618 - val_loss: 0.5381 - val_accuracy: 0.8678 - val_f1_m: 0.8430
# Epoch 5/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0364 - accuracy: 0.9919 - f1_m: 0.9719 - val_loss: 0.5508 - val_accuracy: 0.8699 - val_f1_m: 0.8364
# Epoch 6/20
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0249 - accuracy: 0.9948 - f1_m: 0.9763 - val_loss: 0.8141 - val_accuracy: 0.8571 - val_f1_m: 0.8414
# Epoch 7/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0146 - accuracy: 0.9967 - f1_m: 0.9812 - val_loss: 0.9677 - val_accuracy: 0.8252 - val_f1_m: 0.7988
# Epoch 8/20
# 131/132 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 0.9940 - f1_m: 0.9749Restoring model weights from the end of the best epoch: 3.
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0212 - accuracy: 0.9941 - f1_m: 0.9749 - val_loss: 0.6823 - val_accuracy: 0.8529 - val_f1_m: 0.8333
# Epoch 00008: early stopping
# {'hidden': 'tanh', 'output': 'softmax'}
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 15, 16)            111920
#
#  bidirectional_5 (Bidirectio  (None, 15, 128)          41472
#  nal)
#
#  flatten_5 (Flatten)         (None, 1920)              0
#
#  dense_5 (Dense)             (None, 3)                 5763
#
# =================================================================
# Total params: 159,155
# Trainable params: 159,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 6s 25ms/step - loss: 0.9057 - accuracy: 0.5548 - f1_m: 0.3733 - val_loss: 0.7148 - val_accuracy: 0.6951 - val_f1_m: 0.6558
# Epoch 2/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.4504 - accuracy: 0.8231 - f1_m: 0.8176 - val_loss: 0.4558 - val_accuracy: 0.8593 - val_f1_m: 0.8519
# Epoch 3/20
# 132/132 [==============================] - 2s 18ms/step - loss: 0.1545 - accuracy: 0.9519 - f1_m: 0.9523 - val_loss: 0.5611 - val_accuracy: 0.8571 - val_f1_m: 0.8523
# Epoch 4/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0797 - accuracy: 0.9824 - f1_m: 0.9818 - val_loss: 0.6119 - val_accuracy: 0.8635 - val_f1_m: 0.8658
# Epoch 5/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0408 - accuracy: 0.9886 - f1_m: 0.9892 - val_loss: 0.7134 - val_accuracy: 0.8081 - val_f1_m: 0.8131
# Epoch 6/20
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0348 - accuracy: 0.9896 - f1_m: 0.9898 - val_loss: 0.6441 - val_accuracy: 0.8486 - val_f1_m: 0.8500
# Epoch 7/20
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0228 - accuracy: 0.9941 - f1_m: 0.9944 - val_loss: 0.7420 - val_accuracy: 0.8507 - val_f1_m: 0.8521
# Epoch 8/20
# 132/132 [==============================] - 2s 16ms/step - loss: 0.0171 - accuracy: 0.9960 - f1_m: 0.9959 - val_loss: 0.7394 - val_accuracy: 0.8422 - val_f1_m: 0.8450
# Epoch 9/20
# 131/132 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9974 - f1_m: 0.9974Restoring model weights from the end of the best epoch: 4.
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0099 - accuracy: 0.9972 - f1_m: 0.9971 - val_loss: 0.8468 - val_accuracy: 0.8294 - val_f1_m: 0.8329
# Epoch 00009: early stopping

# %%
# Out:
# 6

# %%
def compareAccuracy(result,activation):
    plt.plot(result[0].history['accuracy'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['accuracy'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['accuracy'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['accuracy'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['accuracy'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['accuracy'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Nilai")
    plt.ylabel("Epochs")
    plt.title("Akurasi Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareAccuracy(result,activation)

# %%
def compareValidationAccuracy(result,activation):
    plt.plot(result[0].history['val_accuracy'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['val_accuracy'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['val_accuracy'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['val_accuracy'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['val_accuracy'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['val_accuracy'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Nilai")
    plt.ylabel("Epochs")
    plt.title("Validasi Akurasi Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareValidationAccuracy(result,activation)

# %%
def compareLoss(result,activation):
    plt.plot(result[0].history['loss'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['loss'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['loss'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['loss'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['loss'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['loss'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Nilai")
    plt.ylabel("Epochs")
    plt.title("Loss Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareLoss(result,activation)

# %%
def compareValidationLoss(result,activation):
    plt.plot(result[0].history['val_loss'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['val_loss'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['val_loss'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['val_loss'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['val_loss'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['val_loss'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Nilai")
    plt.ylabel("Epochs")
    plt.title("Validasi Loss Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareValidationLoss(result,activation)

# %%
def compareF1Score(result,activation):
    plt.plot(result[0].history['f1_m'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['f1_m'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['f1_m'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['f1_m'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['f1_m'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['f1_m'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Nilai")
    plt.ylabel("Epochs")
    plt.title(" F1 Score Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareF1Score(result,activation)

# %%
def compareValidationF1Score(result,activation):
    plt.plot(result[0].history['val_f1_m'],color='b',label='{} + {}'.format(activation[0]['hidden'],activation[0]['output']))
    plt.plot(result[1].history['val_f1_m'],color='g',label='{} + {}'.format(activation[1]['hidden'],activation[1]['output']))
    plt.plot(result[2].history['val_f1_m'],color='r',label='{} + {}'.format(activation[2]['hidden'],activation[2]['output']))
    plt.plot(result[3].history['val_f1_m'],color='c',label='{} + {}'.format(activation[3]['hidden'],activation[3]['output']))
    plt.plot(result[4].history['val_f1_m'],color='m',label='{} + {}'.format(activation[4]['hidden'],activation[4]['output']))
    plt.plot(result[5].history['val_f1_m'],color='y',label='{} + {}'.format(activation[5]['hidden'],activation[5]['output']))
    plt.xlabel("Nilai")
    plt.ylabel("Epochs")
    plt.title(" Validasi F1 Score Berdasarkan Fungsi Aktivasi")
    plt.legend()
    plt.figure(figsize=(200 ,200))
    plt.show()
compareValidationF1Score(result,activation)

# %%
for i in range(6):
    temp=models[i].evaluate(x_test,y_test)
    print("Model dengan hidden layer {} dan output layer {} dengan matrix evaluasi".format(activation[i]['hidden'],activation[i]['output']),temp)
# Out:
# 17/17 [==============================] - 1s 21ms/step - loss: 0.5686 - accuracy: 0.8330 - f1_m: 0.8228
# Model dengan hidden layer relu dan output layer sigmoid dengan matrix evaluasi [0.5685845017433167, 0.8330134153366089, 0.822841227054596]
# 17/17 [==============================] - 0s 19ms/step - loss: 0.6973 - accuracy: 0.8522 - f1_m: 0.8591
# Model dengan hidden layer relu dan output layer softmax dengan matrix evaluasi [0.697337806224823, 0.8522073030471802, 0.8590976595878601]
# 17/17 [==============================] - 0s 17ms/step - loss: 0.7553 - accuracy: 0.8311 - f1_m: 0.7964
# Model dengan hidden layer sigmoid dan output layer sigmoid dengan matrix evaluasi [0.7552704811096191, 0.8310940265655518, 0.7963822484016418]
# 17/17 [==============================] - 0s 20ms/step - loss: 0.5828 - accuracy: 0.8369 - f1_m: 0.8394
# Model dengan hidden layer sigmoid dan output layer softmax dengan matrix evaluasi [0.5827943682670593, 0.8368521928787231, 0.8394221067428589]
# 17/17 [==============================] - 0s 11ms/step - loss: 0.5911 - accuracy: 0.8349 - f1_m: 0.8233
# Model dengan hidden layer tanh dan output layer sigmoid dengan matrix evaluasi [0.5910881757736206, 0.834932804107666, 0.8233401775360107]
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7797 - accuracy: 0.8138 - f1_m: 0.8134
# Model dengan hidden layer tanh dan output layer softmax dengan matrix evaluasi [0.7797166705131531, 0.8138195872306824, 0.8134113550186157]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
for item in models:
    predict=item.predict(x_test)
    confusion=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(predict,axis=1))
    display=ConfusionMatrixDisplay(confusion_matrix=confusion)
    display.plot()

# %%
model=createSimpleModel(1)
history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 15, 16)            111920
#
#  lstm_1 (LSTM)               (None, 15, 64)            20736
#
#  flatten_1 (Flatten)         (None, 960)               0
#
#  dense_1 (Dense)             (None, 3)                 2883
#
# =================================================================
# Total params: 135,539
# Trainable params: 135,539
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Skripsi\Selena Gomez\notebook.ipynb Cell 19 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/notebook.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> model=createSimpleModel(1)
# ----> <a href='vscode-notebook-cell:/d%3A/Skripsi/Selena%20Gomez/notebook.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\engine\training.py:1216, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1209 with tf.profiler.experimental.Trace(
#    1210     'train',
#    1211     epoch_num=epoch,
#    1212     step_num=step,
#    1213     batch_size=batch_size,
#    1214     _r=1):
#    1215   callbacks.on_train_batch_begin(step)
# -> 1216   tmp_logs = self.train_function(iterator)
#    1217   if data_handler.should_sync:
#    1218     context.async_wait()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\def_function.py:910, in Function.__call__(self, *args, **kwds)
#     907 compiler = "xla" if self._jit_compile else "nonXla"
#     909 with OptionalXlaContext(self._jit_compile):
# --> 910   result = self._call(*args, **kwds)
#     912 new_tracing_count = self.experimental_get_tracing_count()
#     913 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\def_function.py:975, in Function._call(self, *args, **kwds)
#     971     pass  # Fall through to cond-based initialization.
#     972   else:
#     973     # Lifting succeeded, so variables are initialized and we can run the
#     974     # stateless function.
# --> 975     return self._stateless_fn(*args, **kwds)
#     976 else:
#     977   _, _, _, filtered_flat_args = \
#     978       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     979           *args, **kwds)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function.__call__(self, *args, **kwargs)
#    3127 with self._lock:
#    3128   (graph_function,
#    3129    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130 return graph_function._call_flat(
#    3131     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\function.py:1959, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1955 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1956 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1957     and executing_eagerly):
#    1958   # No tape is watching; skip to running the function.
# -> 1959   return self._build_call_outputs(self._inference_function.call(
#    1960       ctx, args, cancellation_manager=cancellation_manager))
#    1961 forward_backward = self._select_forward_and_backward_functions(
#    1962     args,
#    1963     possible_gradient_type,
#    1964     executing_eagerly)
#    1965 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\function.py:598, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     596 with _InterpolateFunctionError(self):
#     597   if cancellation_manager is None:
# --> 598     outputs = execute.execute(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#     601         inputs=args,
#     602         attrs=attrs,
#     603         ctx=ctx)
#     604   else:
#     605     outputs = execute.execute_with_cancellation(
#     606         str(self.signature.name),
#     607         num_outputs=self._num_outputs,
#    (...)
#     610         ctx=ctx,
#     611         cancellation_manager=cancellation_manager)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\execute.py:58, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56 try:
#      57   ctx.ensure_initialized()
# ---> 58   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                       inputs, attrs, num_outputs)
#      60 except core._NotOkStatusException as e:
#      61   if name is not None:
#
# KeyboardInterrupt:

# %%
temp=model.evaluate(x_test,y_test)
temp
# Out:
# 17/17 [==============================] - 0s 11ms/step - loss: 0.1171 - accuracy: 0.8100 - f1_m: 0.8079
# [0.11711768805980682, 0.8099808096885681, 0.8078767657279968]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
predict=model.predict(x_test)
confusion=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(predict,axis=1))
display=ConfusionMatrixDisplay(confusion_matrix=confusion)
display.plot()

# %%
import matplotlib.pyplot as plt

def plot_graphs(history):
  figure, axis = plt.subplots(2, 2)
  figure.set_size_inches(18.5, 10.5, forward=True)

  axis[0,0].plot(history.history['accuracy'])
  axis[0,0].plot(history.history['val_accuracy'])
  axis[0,0].set_title('Accuracy')
  axis[0,0].legend(['accuracy','val_accuracy'])

  axis[0,1].plot(history.history['loss'])
  axis[0,1].plot(history.history['val_loss'])
  axis[0,1].set_title('Loss')
  axis[0,1].legend(['loss','val_loss'])

  axis[1,0].plot(history.history['f1_m'])
  axis[1,0].plot(history.history['val_f1_m'])
  axis[1,0].set_title('F1-Score')
  axis[1,0].legend(['f1_m','val_f1_m'])
  plt.show()

# %%
plot_graphs(history=history)

# %%
def createComplexModel(skenario):
    if skenario ==1:
        model=tf.keras.models.Sequential([
            tf.keras.layers.Embedding(len(tokenizer.word_index),128,input_length=max_len),
            tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2),
            tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2),
            tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(512,activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(3, activation='softmax')
        ])
        model.compile(loss='mse',optimizer=tf.keras.optimizers.RMSprop(),metrics=['accuracy',f1_m])
    else:
        model=tf.keras.models.Sequential([
        tf.keras.layers.Embedding(len(tokenizer.word_index),128,input_length=max_len),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128,return_sequences=True,activation='tanh',dropout=0.2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512,activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(3,activation='softmax')
        ])
        model.compile(loss='mse',optimizer=tf.keras.optimizers.RMSprop(),metrics=['accuracy',f1_m])
    model.summary()
    return model

# %%
model=createComplexModel(2)
history=model.fit(x_train,y_train,epochs=20,validation_split=0.1,callbacks=[callback])
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_10 (Embedding)    (None, 15, 128)           895360
#
#  bidirectional_12 (Bidirecti  (None, 15, 256)          263168
#  onal)
#
#  bidirectional_13 (Bidirecti  (None, 15, 256)          394240
#  onal)
#
#  bidirectional_14 (Bidirecti  (None, 15, 256)          394240
#  onal)
#
#  flatten_10 (Flatten)        (None, 3840)              0
#
#  dense_18 (Dense)            (None, 512)               1966592
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_19 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 3,915,139
# Trainable params: 3,915,139
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 132/132 [==============================] - 18s 55ms/step - loss: 0.8239 - accuracy: 0.6321 - f1_m: 0.5431 - val_loss: 0.5873 - val_accuracy: 0.7932 - val_f1_m: 0.7701
# Epoch 2/20
# 132/132 [==============================] - 5s 38ms/step - loss: 0.3966 - accuracy: 0.8653 - f1_m: 0.8647 - val_loss: 0.5742 - val_accuracy: 0.7996 - val_f1_m: 0.8013
# Epoch 3/20
# 132/132 [==============================] - 5s 37ms/step - loss: 0.2500 - accuracy: 0.9227 - f1_m: 0.9212 - val_loss: 0.3869 - val_accuracy: 0.8678 - val_f1_m: 0.8560
# Epoch 4/20
# 132/132 [==============================] - 5s 40ms/step - loss: 0.1565 - accuracy: 0.9542 - f1_m: 0.9539 - val_loss: 0.4261 - val_accuracy: 0.8401 - val_f1_m: 0.8421
# Epoch 5/20
# 132/132 [==============================] - 5s 38ms/step - loss: 0.1231 - accuracy: 0.9635 - f1_m: 0.9626 - val_loss: 0.4509 - val_accuracy: 0.8571 - val_f1_m: 0.8539
# Epoch 6/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.1005 - accuracy: 0.9720 - f1_m: 0.9722 - val_loss: 0.3989 - val_accuracy: 0.8699 - val_f1_m: 0.8620
# Epoch 7/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0775 - accuracy: 0.9763 - f1_m: 0.9766 - val_loss: 0.5164 - val_accuracy: 0.8785 - val_f1_m: 0.8808
# Epoch 8/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0611 - accuracy: 0.9817 - f1_m: 0.9817 - val_loss: 0.4865 - val_accuracy: 0.8785 - val_f1_m: 0.8807
# Epoch 9/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0544 - accuracy: 0.9848 - f1_m: 0.9846 - val_loss: 0.6683 - val_accuracy: 0.8507 - val_f1_m: 0.8520
# Epoch 10/20
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0439 - accuracy: 0.9879 - f1_m: 0.9878 - val_loss: 1.9408 - val_accuracy: 0.8721 - val_f1_m: 0.8714
# Epoch 11/20
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0470 - accuracy: 0.9886 - f1_m: 0.9887 - val_loss: 0.9230 - val_accuracy: 0.8763 - val_f1_m: 0.8794
# Epoch 12/20
# 131/132 [============================>.] - ETA: 0s - loss: 0.0319 - accuracy: 0.9921 - f1_m: 0.9921- ETA: 0s - loss: 0.0313 - accuracy: 0.9927 - Restoring model weights from the end of the best epoch: 7.
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0317 - accuracy: 0.9922 - f1_m: 0.9922 - val_loss: 1.1515 - val_accuracy: 0.8614 - val_f1_m: 0.8668
# Epoch 00012: early stopping

# %%
temp=model.evaluate(x_test,y_test)
temp
# Out:
# 17/17 [==============================] - 1s 32ms/step - loss: 0.5319 - accuracy: 0.8580 - f1_m: 0.8578
# [0.5319363474845886, 0.8579654693603516, 0.8578073382377625]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
predict=model.predict(x_test)
confusion=confusion_matrix(np.argmax(y_test,axis=1),np.argmax(predict,axis=1))
display=ConfusionMatrixDisplay(confusion_matrix=confusion)
display.plot()

# %%
plot_graphs(history=history)
