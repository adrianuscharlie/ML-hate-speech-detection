# %%
import pandas as pd
import Sastrawi
import googletrans
import re

# %%
data=pd.read_excel('D:/Skripsi/Data/english.xlsx')
del data['Unnamed: 0']
data
# Out:
#       created at         username  \
# 0     2022-11-02       rudiartraa
# 1     2022-11-02      oi_filix315
# 2     2022-11-01    falahsanjaya_
# 3     2022-11-01     namanyaajess
# 4     2022-11-01       namakubaim
# ...          ...              ...
# 19995 2022-09-11  SecretAdmirerOP
# 19996 2022-09-11        yonforger
# 19997 2022-09-11     semangkalucu
# 19998 2022-09-11         choaciao
# 19999 2022-09-11          JrIzzah
#
#                                                     text  \
# 0          yaah , udah selesai nih Bjorka Bjorkaan nya ?
# 1      Kadang gua mikir sekilas pp gua mirip bjorka, ...
# 2      Knp ga ada yg jadi Bjorka Halloween party kema...
# 3      Beritanya taik, mau ferdi sambo, mau bjorka, m...
# 4                                      Apa kabar Bjorka?
# ...                                                  ...
# 19995  hari ini ada 2 hari bersejarah\n9/11\nbjorka s...
# 19996  lah anjir aku baru tau bjorka tu hacker, kirai...
# 19997  kata w mending bjorka ngewarin tiket the link aja
# 19998  Bang bjorka bisa ga si hek hati doi biar sama ...
# 19999  Bjorka mending liat data Kominfo daripada data...
#
#                                                  english
# 0               Yeah, have you finished Bjorka Bjorkaan?
# 1      Sometimes I think my pp at a glance is like Bj...
# 2      Why didn't anyone become a Bjorka Halloween Pa...
# 3      The news is not, want Ferdy Sambo, want Bjorka...
# 4                                        How are Bjorka?
# ...                                                  ...
# 19995  Today there are 2 historic days \n 9/11 \n Bjo...
# 19996  I just found out bjorka tu hacker, I think bur...
# 19997  said wa pending bjorka released the link the link
# 19998                      Bang bjorka can not hek heart
# 19999  Bjorka is better to see the Ministry of Commun...
#
# [20000 rows x 4 columns]

# %%
import translators as ts
# Out:
# Using state Central Java server backend.

# %%
def translate(dataframe,awal,akhir):
    for i in range(awal,akhir):
        try:
            dataframe['english'][i]=ts.google(dataframe['english'][i],from_language='id',to_language='en')
            print("iterasi ke-",i,dataframe['english'][i])
        except:
            print("Stop pada iterasi ke-",i)
            return dataframe
    return dataframe

# %%
data=translate(data,20000,20001)
data
# Out:
# Stop pada iterasi ke- 20000
#       created at         username  \
# 0     2022-11-02       rudiartraa
# 1     2022-11-02      oi_filix315
# 2     2022-11-01    falahsanjaya_
# 3     2022-11-01     namanyaajess
# 4     2022-11-01       namakubaim
# ...          ...              ...
# 19995 2022-09-11  SecretAdmirerOP
# 19996 2022-09-11        yonforger
# 19997 2022-09-11     semangkalucu
# 19998 2022-09-11         choaciao
# 19999 2022-09-11          JrIzzah
#
#                                                     text  \
# 0               Yeah, have you finished Bjorka Bjorkaan?
# 1      Sometimes I think my pp at a glance is like Bj...
# 2      Why didn't anyone become a Bjorka Halloween Pa...
# 3      The news is not, want Ferdy Sambo, want Bjorka...
# 4                                        How are Bjorka?
# ...                                                  ...
# 19995  hari ini ada 2 hari bersejarah\n9/11\nbjorka s...
# 19996  lah anjir aku baru tau bjorka tu hacker, kirai...
# 19997  kata w mending bjorka ngewarin tiket the link aja
# 19998  Bang bjorka bisa ga si hek hati doi biar sama ...
# 19999  Bjorka mending liat data Kominfo daripada data...
#
#                                                  english
# 0               Yeah, have you finished Bjorka Bjorkaan?
# 1      Sometimes I think my pp at a glance is like Bj...
# 2      Why didn't anyone become a Bjorka Halloween Pa...
# 3      The news is not, want Ferdy Sambo, want Bjorka...
# 4                                        How are Bjorka?
# ...                                                  ...
# 19995  Today there are 2 historic days \n 9/11 \n Bjo...
# 19996  I just found out bjorka tu hacker, I think bur...
# 19997  said wa pending bjorka released the link the link
# 19998                      Bang bjorka can not hek heart
# 19999  Bjorka is better to see the Ministry of Commun...
#
# [20000 rows x 4 columns]

# %%
data.to_excel('english.xlsx')

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
def sentiment_scores(sentence):
 
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
 
    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)
     
 
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0.05 :
        return "Positive"
 
    elif sentiment_dict['compound'] <= - 0.05 :
        return "Negative"
 
    else :
        return "Neutral"

def sentiment_score2(sentence):
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
 
    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)
     
 
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0 :
        return "Positive"
 
    else :
        return "Negative"

# %%
data['sentiment']=data['english'].apply(sentiment_scores)
data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Skripsi\data_preprocessing.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Skripsi/data_preprocessing.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> data['sentiment']=data['english'].apply(sentiment_scores)
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/data_preprocessing.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> data
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# -> 1088 return self.apply_standard()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\apply.py:1143, in SeriesApply.apply_standard(self)
#    1137         values = obj.astype(object)._values
#    1138         # error: Argument 2 to "map_infer" has incompatible type
#    1139         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1140         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1141         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142         # "Callable[[Any], Any]"
# -> 1143         mapped = lib.map_infer(
#    1144             values,
#    1145             f,  # type: ignore[arg-type]
#    1146             convert=self.convert_dtype,
#    1147         )
#    1149 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1150     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1151     #  See also GH#25959 regarding EA support
#    1152     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# d:\Skripsi\data_preprocessing.ipynb Cell 8 in sentiment_scores(sentence)
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/data_preprocessing.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> def sentiment_scores(sentence):
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/data_preprocessing.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>
#       <a href='vscode-notebook-cell:/d%3A/Skripsi/data_preprocessing.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>     # Create a SentimentIntensityAnalyzer object.
# ----> <a href='vscode-notebook-cell:/d%3A/Skripsi/data_preprocessing.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>     sid_obj = SentimentIntensityAnalyzer()
#      <a href='vscode-notebook-cell:/d%3A/Skripsi/data_preprocessing.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a>     # polarity_scores method of SentimentIntensityAnalyzer
#      <a href='vscode-notebook-cell:/d%3A/Skripsi/data_preprocessing.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a>     # object gives a sentiment dictionary.
#      <a href='vscode-notebook-cell:/d%3A/Skripsi/data_preprocessing.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a>     # which contains pos, neg, neu, and compound scores.
#      <a href='vscode-notebook-cell:/d%3A/Skripsi/data_preprocessing.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a>     sentiment_dict = sid_obj.polarity_scores(sentence)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\vaderSentiment\vaderSentiment.py:206, in SentimentIntensityAnalyzer.__init__(self, lexicon_file, emoji_lexicon)
#     203 self.lexicon = self.make_lex_dict()
#     205 emoji_full_filepath = os.path.join(os.path.dirname(_this_module_file_path_), emoji_lexicon)
# --> 206 with codecs.open(emoji_full_filepath, encoding='utf-8') as f:
#     207     self.emoji_full_filepath = f.read()
#     208 self.emojis = self.make_emoji_dict()
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\codecs.py:905, in open(filename, mode, encoding, errors, buffering)
#     901 if encoding is not None and \
#     902    'b' not in mode:
#     903     # Force opening of the file in binary mode
#     904     mode = mode + 'b'
# --> 905 file = builtins.open(filename, mode, buffering)
#     906 if encoding is None:
#     907     return file
#
# KeyboardInterrupt:

# %%
data.to_excel('')

# %%
import pandas as pd
data=pd.read_excel('D:/Skripsi/Data/english_sentiment.xlsx')
del data['Unnamed: 0']
data
# Out:
#       created at         username  \
# 0     2022-11-02       rudiartraa
# 1     2022-11-02      oi_filix315
# 2     2022-11-01    falahsanjaya_
# 3     2022-11-01     namanyaajess
# 4     2022-11-01       namakubaim
# ...          ...              ...
# 19995 2022-09-11  SecretAdmirerOP
# 19996 2022-09-11        yonforger
# 19997 2022-09-11     semangkalucu
# 19998 2022-09-11         choaciao
# 19999 2022-09-11          JrIzzah
#
#                                                     text  \
# 0          yaah , udah selesai nih Bjorka Bjorkaan nya ?
# 1      Kadang gua mikir sekilas pp gua mirip bjorka, ...
# 2      Knp ga ada yg jadi Bjorka Halloween party kema...
# 3      Beritanya taik, mau ferdi sambo, mau bjorka, m...
# 4                                      Apa kabar Bjorka?
# ...                                                  ...
# 19995  hari ini ada 2 hari bersejarah\n9/11\nbjorka s...
# 19996  lah anjir aku baru tau bjorka tu hacker, kirai...
# 19997  kata w mending bjorka ngewarin tiket the link aja
# 19998  Bang bjorka bisa ga si hek hati doi biar sama ...
# 19999  Bjorka mending liat data Kominfo daripada data...
#
#                                                  english sentiment
# 0               Yeah, have you finished Bjorka Bjorkaan?  Positive
# 1      Sometimes I think my pp at a glance is like Bj...  Positive
# 2      Why didn't anyone become a Bjorka Halloween Pa...  Positive
# 3      The news is not, want Ferdy Sambo, want Bjorka...  Negative
# 4                                        How are Bjorka?   Neutral
# ...                                                  ...       ...
# 19995  Today there are 2 historic days \n 9/11 \n Bjo...  Negative
# 19996  I just found out bjorka tu hacker, I think bur...   Neutral
# 19997  said wa pending bjorka released the link the link   Neutral
# 19998                      Bang bjorka can not hek heart  Negative
# 19999  Bjorka is better to see the Ministry of Commun...  Positive
#
# [20000 rows x 5 columns]

# %%
data['sentiment'].value_counts()
# Out:
# Positive    8025
# Neutral     6772
# Negative    5203
# Name: sentiment, dtype: int64

# %%
import re
import numpy as np

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory=StemmerFactory()
stemmer=factory.create_stemmer()

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

# %%
kamus_alay=pd.read_csv('data/new_kamusalay.csv',header=None,encoding='latin-1')
kamus_alay=kamus_alay.rename(columns={0:'asli',1:'baru'})
kamus_alay
# Out:
#                       asli                               baru
# 0      anakjakartaasikasik           anak jakarta asyik asyik
# 1             pakcikdahtua                  pak cik sudah tua
# 2           pakcikmudalagi                  pak cik muda lagi
# 3              t3tapjokowi                       tetap jokowi
# 4                       3x                          tiga kali
# ...                    ...                                ...
# 15162            mendikbud  menteri pendidikan dan kebudayaan
# 15163               mendag                menteri perdagangan
# 15164              menaker               menteri tenaga kerja
# 15165             memetwit                            mentwit
# 15166             megangin                           memegang
#
# [15167 rows x 2 columns]

# %%
def removeUnicode(text):
    """ Removes unicode strings like "\u002c" and "x96" """
    text = re.sub(r'(\\u[0-9A-Fa-f]+)',r'', text)       
    text = re.sub(r'[^\x00-\x7f]',r'',text)
    return text

# %%
#Lower text
def lowercase(text):
    return text.lower()

# %%
#Remove non alphanumeric character
def removeNonAlphanumeric(text):
    text = re.sub('[^0-9a-zA-Z]+', ' ', text) 
    text="".join(filter(lambda x: not x.isdigit(), text))
    return text

# %%
def removeNumbers(text):
    text = ''.join([i for i in text if not i.isdigit()])         
    return text

# %%
#Remove unnecessary charracters
def removeUnnecessary(text):
    text=re.sub('\n','',text) # menghapus newline
    text=re.sub('rt','',text) # menghapus kata retweet
    text=re.sub('user','',text) # menghapus kata user
    text=re.sub('((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))','',text) # menghapus url
    text = re.sub('  +', ' ', text) # menghapus karakter ekstra
    text=re.sub('x.{3} | x.{2}','',text) # menghapus pola emoji 
    return text

# %%
#normalize alay
alay=dict(zip(kamus_alay['asli'],kamus_alay['baru']))
def normalizeAlay(text):
    return ' '.join([alay[word] if word in alay else word for word in text.split(' ')])

# %%
#Stemming text
def stemWord(x):
    return stemmer.stem(x)

# %%
#remove indonesian stopword
def removeStopWord(text):
    text=stopword.remove(text)
    return text

# %%
def preProcessing(sentences):
    sentences=lowercase(sentences)
    sentences=removeNonAlphanumeric(sentences)
    sentences=removeUnnecessary(sentences)
    sentences=normalizeAlay(sentences)
    sentences=stemWord(sentences)
    sentences=removeStopWord(sentences)
    return sentences

# %%
data['preprocessed']=data['text'].apply(lowercase)
data['preprocessed']
# Out:
# 0            yaah , udah selesai nih bjorka bjorkaan nya ?
# 1        kadang gua mikir sekilas pp gua mirip bjorka, ...
# 2        knp ga ada yg jadi bjorka halloween party kema...
# 3        beritanya taik, mau ferdi sambo, mau bjorka, m...
# 4                                        apa kabar bjorka?
#                                ...
# 19995    hari ini ada 2 hari bersejarah\n9/11\nbjorka s...
# 19996    lah anjir aku baru tau bjorka tu hacker, kirai...
# 19997    kata w mending bjorka ngewarin tiket the link aja
# 19998    bang bjorka bisa ga si hek hati doi biar sama ...
# 19999    bjorka mending liat data kominfo daripada data...
# Name: preprocessed, Length: 20000, dtype: object

# %%
data['preprocessed']=data['preprocessed'].apply(removeNonAlphanumeric)
data['preprocessed']
# Out:
# 0               yaah udah selesai nih bjorka bjorkaan nya
# 1        kadang gua mikir sekilas pp gua mirip bjorka t...
# 2        knp ga ada yg jadi bjorka halloween party kema...
# 3        beritanya taik mau ferdi sambo mau bjorka mau ...
# 4                                        apa kabar bjorka
#                                ...
# 19995    hari ini ada  hari bersejarah   bjorka spill d...
# 19996    lah anjir aku baru tau bjorka tu hacker kirain...
# 19997    kata w mending bjorka ngewarin tiket the link aja
# 19998    bang bjorka bisa ga si hek hati doi biar sama ...
# 19999    bjorka mending liat data kominfo daripada data...
# Name: preprocessed, Length: 20000, dtype: object

# %%
data['preprocessed']=data['preprocessed'].apply(removeUnnecessary)
data['preprocessed']
# Out:
# 0               yaah udah selesai nih bjorka bjorkaan nya
# 1        kadang gua mikir sekilas pp gua mirip bjorka t...
# 2         knp ga ada yg jadi bjorka halloween pay kemaren
# 3        beritanya taik mau ferdi sambo mau bjorka mau ...
# 4                                        apa kabar bjorka
#                                ...
# 19995    hari ini ada hari bersejarah bjorka spill data...
# 19996    lah anjir aku baru tau bjorka tu hacker kirain...
# 19997    kata w mending bjorka ngewarin tiket the link aja
# 19998    bang bjorka bisa ga si hek hati doi biar sama ...
# 19999    bjorka mending liat data kominfo daripada data...
# Name: preprocessed, Length: 20000, dtype: object

# %%
data['preprocessed']=data['preprocessed'].apply(normalizeAlay)
data['preprocessed']
# Out:
# 0                ya sudah selesai nih bjorka bjorkaan nya
# 1        kadang gue pikir sekilas pp gue mirip bjorka t...
# 2        kenapa tidak ada yang jadi bjorka halloween pa...
# 3        beritanya tai mau ferdi sambo mau bjorka mau a...
# 4                                        apa kabar bjorka
#                                ...
# 19995    hari ini ada hari bersejarah bjorka spill data...
# 19996    lah anjir aku baru tau bjorka itu hacker kiraa...
# 19997    kata gue mending bjorka ngewarin tiket the lin...
# 19998    bang bjorka bisa tidak sih hek hati dia biar s...
# 19999    bjorka mending lihat data kominfo daripada dat...
# Name: preprocessed, Length: 20000, dtype: object

# %%
data['preprocessed']=data['preprocessed'].apply(stemWord)
data['preprocessed']
# Out:
# 0                 ya sudah selesai nih bjorka bjorkaan nya
# 1        kadang gue pikir kilas pp gue mirip bjorka tap...
# 2        kenapa tidak ada yang jadi bjorka halloween pa...
# 3        berita tai mau ferdi sambo mau bjorka mau apa ...
# 4                                         apa kabar bjorka
#                                ...
# 19995    hari ini ada hari sejarah bjorka spill data bu...
# 19996    lah anjir aku baru tau bjorka itu hacker kira ...
# 19997    kata gue mending bjorka ngewarin tiket the lin...
# 19998    bang bjorka bisa tidak sih hek hati dia biar s...
# 19999    bjorka mending lihat data kominfo daripada dat...
# Name: preprocessed, Length: 20000, dtype: object

# %%
data['preprocessed']=data['preprocessed'].apply(removeStopWord)
data['preprocessed']
# Out:
# 0                              selesai nih bjorka bjorkaan
# 1        kadang gue pikir kilas pp gue bjorka gue pakai pp
# 2                             bjorka halloween pay kemarin
# 3        berita tai ferdi sambo bjorka lapar tren topik...
# 4                                             kabar bjorka
#                                ...
# 19995            sejarah bjorka spill data bunuh munir tau
# 19996    anjir tau bjorka hacker bubur kacang ijo tukan...
# 19997           gue mending bjorka ngewarin tiket the link
# 19998                 bang bjorka sih hek hati biar ghuweh
# 19999              bjorka mending data kominfo data wifiku
# Name: preprocessed, Length: 20000, dtype: object

# %%
data['preprocessed']=data['text'].apply(preProcessing)
data
# Out:
#       created at         username  \
# 0     2022-11-02       rudiartraa
# 1     2022-11-02      oi_filix315
# 2     2022-11-01    falahsanjaya_
# 3     2022-11-01     namanyaajess
# 4     2022-11-01       namakubaim
# ...          ...              ...
# 19995 2022-09-11  SecretAdmirerOP
# 19996 2022-09-11        yonforger
# 19997 2022-09-11     semangkalucu
# 19998 2022-09-11         choaciao
# 19999 2022-09-11          JrIzzah
#
#                                                     text  \
# 0          yaah , udah selesai nih Bjorka Bjorkaan nya ?
# 1      Kadang gua mikir sekilas pp gua mirip bjorka, ...
# 2      Knp ga ada yg jadi Bjorka Halloween party kema...
# 3      Beritanya taik, mau ferdi sambo, mau bjorka, m...
# 4                                      Apa kabar Bjorka?
# ...                                                  ...
# 19995  hari ini ada 2 hari bersejarah\n9/11\nbjorka s...
# 19996  lah anjir aku baru tau bjorka tu hacker, kirai...
# 19997  kata w mending bjorka ngewarin tiket the link aja
# 19998  Bang bjorka bisa ga si hek hati doi biar sama ...
# 19999  Bjorka mending liat data Kominfo daripada data...
#
#                                                  english sentiment  \
# 0               Yeah, have you finished Bjorka Bjorkaan?  Positive
# 1      Sometimes I think my pp at a glance is like Bj...  Positive
# 2      Why didn't anyone become a Bjorka Halloween Pa...  Positive
# 3      The news is not, want Ferdy Sambo, want Bjorka...  Negative
# 4                                        How are Bjorka?  Positive
# ...                                                  ...       ...
# 19995  Today there are 2 historic days \n 9/11 \n Bjo...  Negative
# 19996  I just found out bjorka tu hacker, I think bur...  Positive
# 19997  said wa pending bjorka released the link the link  Positive
# 19998                      Bang bjorka can not hek heart  Negative
# 19999  Bjorka is better to see the Ministry of Commun...  Positive
#
#                                             preprocessed
# 0                            selesai nih bjorka bjorkaan
# 1      kadang gue pikir kilas pp gue bjorka gue pakai pp
# 2                           bjorka halloween pay kemarin
# 3      berita tai ferdi sambo bjorka lapar tren topik...
# 4                                           kabar bjorka
# ...                                                  ...
# 19995          sejarah bjorka spill data bunuh munir tau
# 19996  anjir tau bjorka hacker bubur kacang ijo tukan...
# 19997         gue mending bjorka ngewarin tiket the link
# 19998               bang bjorka sih hek hati biar ghuweh
# 19999            bjorka mending data kominfo data wifiku
#
# [20000 rows x 6 columns]

# %%
data.to_excel('D:/Skripsi/Data/english_sentiment_clean_2polarity.xlsx')
